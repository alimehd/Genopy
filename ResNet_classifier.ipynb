# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from os import path
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, models
import datetime
import socket
import random
import easydict
from pytz import timezone
import operator
import pandas as pd

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from IPython.display import Image

import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler    
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %matplotlib inline

# %%
tz = timezone('US/Eastern')

path = "/content/drive/MyDrive/D3data_allcont_3983/" # data directory

# train data
train_wo_file = "train_without_missing.txt"
train_w_file = "train_with_missing.txt"
train_meta = "train.meta"

# validation data
validation_wo_file = "validation_without_missing.txt"
validation_w_file = "validation_with_missing.txt"
validation_meta = "validation.meta"

# test data
test_wo_file = "test_without_missing.txt"
test_w_file = "test_with_missing.txt"
test_meta = "test.meta"

# checkpoint_epoch = 10
checkpoint = None

args = easydict.EasyDict({
    "log_name": "imputation_model",
    "model_type": "mlp",
    "nb_epochs":500,
    "bottleneck_dim":1024,
    "encoder_dim":6,
    "dencoder_dim":6,
    "encoder_dim":0,
    "dencoder_dim":0,
    "batch_size":64,
    "seq_len":3983,
    "learning_rate":0.00001,
    "betal":0.5,
    "seed":1,
    "missing_char":".",
    "resnet_mix":0.5,
    "optimizer":"adam",
    "haplotype_cutoff":1.0,
    "filter_size":7,
    "with_region_metadata":True,
    "continent": False,
    "save_model": True,
    "latent_dim":64,
    "gen_dim": 16,
    "disc_dim": 16,
    "gen_layers":1,
    "disc_layers": 1,
    "beta1": 0.5,
    "save_embedded_haplotypes": True,
    "vocab_size": 5,
    "train": True
})

os.environ["CUDA_VISIBLE_DEVICES"]="0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

seed = args.seed
torch.backends.cudnn.deterministic = True
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

charmap = {"A":0, "C":1, "G":2, "T":3, args.missing_char:4}
charmap_rev = {0:"A", 1:"C", 2:"G", 3:"T"}

# %% [markdown]
# Collect metadata info

# %%
df_train = pd.read_csv(path + train_meta, sep = '\t',header=None)
df_validation = pd.read_csv(path +validation_meta, sep='\t', header=None)
df_test = pd.read_csv(path+ test_meta, sep='\t', header=None)

# %%
df_train=df_train.fillna("NaN")
df_validation=df_validation.fillna("NaN")
df_test=df_test.fillna("NaN")

# %%
df_validation.head()
# Out:
#              0              1               2
# 0   ERR4243046         Europe  United Kingdom
# 1   ERR4085434         Europe  United Kingdom
# 2  SRR11621827  North America             USA
# 3   ERR4204618         Europe  United Kingdom
# 4   ERR4305040         Europe  United Kingdom

# %%
df_train[1].value_counts()
# Out:
# Europe           4817
# Oceania           924
# North America     872
# Asia               88
# Africa             87
# Name: 1, dtype: int64

# %%
df_validation[1].value_counts()
# Out:
# Europe           1581
# North America     315
# Oceania           303
# Africa             33
# Asia               31
# Name: 1, dtype: int64

# %%
df_test[1].value_counts()
# Out:
# Europe           1623
# Oceania           294
# North America     290
# Africa             30
# Asia               26
# Name: 1, dtype: int64

# %%
countries = {region:i for i, region in enumerate(sorted(set(df_train[1])|set(df_validation[1])|set(df_test[1])))}
countries['NaN'] = len(countries) 
print(countries)
# Out:
# {'Africa': 0, 'Asia': 1, 'Europe': 2, 'North America': 3, 'Oceania': 4, 'NaN': 5}

# %%
if args.continent:
    meta_region = continents
else:
    meta_region = countries

# %%
def charmap_to_onehots(chars, charmap, model_type="resnet2d"):
    onehots = np.int_(np.zeros([len(chars),len(charmap)]))
    I = np.eye(len(charmap))
    for i, char in enumerate(chars):
        onehots[i] = I[charmap[char]]
        
    if model_type == "mlp":
        onehots = np.reshape(onehots, [-1])
    if model_type == "resnet1d" or model_type == "resnet2d":
        onehots = onehots.T
    return onehots

def metadata_to_one_hot(data, nb_classes, model_type = "resnet2d"):
    targets = np.array(data).reshape(-1)
    return np.eye(nb_classes)[targets].astype(int)[0]

def listToDict(lst):
    op = {lst[i].strip(): lst[i+1].strip() for i in range(0,len(lst), 2)}
    return op
        
    
# for GANs

def get_generator_block(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, output_dim),
        nn.BatchNorm1d(output_dim),
        nn.ReLU(inplace=True)
    )

def get_noise(n_samples, z_dim, device='cpu'):
    return torch.randn(n_samples, z_dim, device=device)

def get_discriminator_block(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, output_dim),
        nn.LeakyReLU(0.2, inplace=True)
    )

def get_disc_loss(gen, disc, criterion, real, num_images, z_dim, device):
    fake_noise = get_noise(num_images, z_dim, device=device)
    fake = gen(fake_noise)
    disc_fake_pred = disc(fake.detach())
    disc_fake_loss = criterion(disc_fake_pred, torch.zeros_like(disc_fake_pred))
    disc_real_pred = disc(real)
    disc_real_loss = criterion(disc_real_pred, torch.ones_like(disc_real_pred))
    disc_loss = (disc_fake_loss + disc_real_loss) / 2
    return disc_loss

def get_gen_loss(gen, disc, criterion, num_images, z_dim, device):
    fake_noise = get_noise(num_images, z_dim, device=device)
    fake = gen(fake_noise)
    disc_fake_pred = disc(fake)
    gen_loss = criterion(disc_fake_pred, torch.ones_like(disc_fake_pred))
    return gen_loss

# %% [markdown]
# ## Initiate the Dataset Class:

# %%
class CovidDataset(Dataset):
    def __init__(self, path, files, model, split="train", 
                 charmap=charmap, haplotype_cutoff=args.haplotype_cutoff, 
                 meta_continent=args.continent, meta_region=meta_region):
        """
        Args:
            :param path: path to dataset file
            :param file: dataset file name
            :param model: model of interest to work with
            :charmap: dict that maps nucleotides into digits which represet indexes of vectors in one-hot matrix
            ...
        """        
        self.dataset = {}
        for file in files[0]:
            with open(os.path.join(path, file), 'r') as f:
                content = f.readlines()
                templist = []
                for line in content:
                    seq_id, seq = line.strip().split("\t",1)
                    templist.append(seq_id)
                    templist.append(seq.replace("\t", ""))
                self.dataset = {**self.dataset, **listToDict(templist)}
                print("number of samples with duplication:", len(list(self.dataset.values())))
                print("number of samples without duplication:", len(set(list(self.dataset.values()))))
                #self.dataset = {**self.dataset, **listToDict(content)}
        self.dataset_new = {}
        for k, v in self.dataset.items(): # not including seq. with many miss. val. (based on haplotype_cutoff)
            if '.' in v:
                if v.count('.')/len(v) <= args.haplotype_cutoff: 
                    self.dataset_new[k] = v
            else:
                self.dataset_new[k] = v
        self.dataset = self.dataset_new
        #print(self.dataset)
        
        self.sequences = [charmap_to_onehots(sequence, charmap, model) for sequence in list(self.dataset.values())]
        self.ids = list(range(len(list(self.dataset))))
        
        index = 0
        if args.continent: index = 2 # for continent
        else: index = 1 # for country
            
        meta_place = {}        
        for file in files[1]:
            df = pd.read_csv(path + file, sep='\t', lineterminator='\n', header=None)
            df = df.fillna("NaN")
            meta_temp = {name:place for name, place in zip(list(df[0]), list(df[index]))}
            meta_place = {**meta_place, **meta_temp}
            
        self.meta_place = {}
        for i, name in enumerate(self.dataset):
            self.meta_place[i] = metadata_to_one_hot(meta_region[meta_place[name]], len(meta_region)+1)
            
    def __getitem__(self, i):
        id = self.ids[i]
        return self.sequences[id], self.meta_place[id]
    
    def __len__(self):
        return len(self.ids)

# %%
dataset_train = CovidDataset(path, [[train_w_file], [train_meta]], args.model_type)
dataset_validation = CovidDataset(path, [[validation_w_file], [validation_meta]], args.model_type)
dataset_test = CovidDataset(path, [[test_w_file], [test_meta]], args.model_type)
# Out:
# number of samples with duplication: 6788
# number of samples without duplication: 5213
# number of samples with duplication: 2263
# number of samples without duplication: 1821
# number of samples with duplication: 2263
# number of samples without duplication: 1785

# %%
dataloader_train = DataLoader(dataset_train, args.batch_size, drop_last = True, shuffle = True)
dataloader_validation = DataLoader(dataset_validation, args.batch_size,drop_last=False,shuffle= False)
dataloader_test = DataLoader(dataset_test, args.batch_size,drop_last=False,shuffle= False)

# %%
len(dataloader_train)
# dataloader -> model -> criterion -> optimizer -> training loop
# Out:
# 106

# %%
len(dataloader_validation)
# Out:
# 36

# %%
examples = iter(dataloader_train)
samples, labels = examples.next()
print(samples.shape, labels.shape)
# Out:
# torch.Size([64, 19915]) torch.Size([64, 7])

# %%
class EarlyStopping(object):
    def __init__(self, mode='min', min_delta=0, patience=10, percentage=False):
        self.mode = mode
        self.min_delta = min_delta
        self.patience = patience
        self.best = None
        self.num_bad_epochs = 0
        self.is_better = None
        self._init_is_better(mode, min_delta, percentage)

        if patience == 0:
            self.is_better = lambda a, b: True
            self.step = lambda a: False

    def step(self, metrics):
        if self.best is None:
            self.best = metrics
            return False

        if torch.isnan(metrics):
            return True

        if self.is_better(metrics, self.best):
            self.num_bad_epochs = 0
            self.best = metrics
        else:
            self.num_bad_epochs += 1

        if self.num_bad_epochs >= self.patience:
            return True

        return False

    def _init_is_better(self, mode, min_delta, percentage):
        if mode not in {'min', 'max'}:
            raise ValueError('mode ' + mode + ' is unknown!')
        if not percentage:
            if mode == 'min':
                self.is_better = lambda a, best: a < best - min_delta
            if mode == 'max':
                self.is_better = lambda a, best: a > best + min_delta
        else:
            if mode == 'min':
                self.is_better = lambda a, best: a < best - (
                            best * min_delta / 100)
            if mode == 'max':
                self.is_better = lambda a, best: a > best + (
                            best * min_delta / 100)

# %%
def save_models(logdir, generator, discriminator, true_count):
    """Function to save Denerator and Discriminator models (checkpointing)"""
    ckpt_dir = os.path.join(logdir, "checkpoints", "checkpoint_{}".format(true_count))
    os.makedirs(ckpt_dir, exist_ok=True)
    torch.save(generator.state_dict(), '{}/netG'.format(ckpt_dir))
    torch.save(discriminator.state_dict(), '{}/netD'.format(ckpt_dir))

# %% [markdown]
# # Model: Multi-Layer Perceptron

# %%
class mlp_generator(nn.Module):
    """ Multi-Layer Perceptron for generating sequences.

    Parameters:
        inputs (tensor):Batch of noises inputed to the network.
        dim (int):Generator dimension parameter (in each middle layer).
        input_size (int):Size of latent space (i.e., the first layer dimension).
        output_size (int):Size of the last layer (=max_seq_len*vocab_size).
        num_layers (int):How many middle or hidden layers for generator.

    Returns:
        outputs (tensor):Batch of lists of values (each `vocab_size` interval represents one nucleotide).   

    """
    def __init__(self, dim=64, input_size=19915, output_size=3, num_layers=4): # 5 x 3983
        super(mlp_generator, self).__init__()

        num_layers = num_layers + 2  # add 2 for the 1st and the last layers
        modules = []
        for layer in range(num_layers): 
            in_size = input_size if layer == 0 else dim
            out_size = output_size if layer == num_layers - 1 else dim
            if layer < num_layers - 1:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                        nn.ReLU(True),
                    )
                )
            else:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                        nn.Sigmoid()
                    )
                )
        self.layers = nn.Sequential(*modules)
        
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.layers(x)
        return x

# rename to mlp_classifier
# outsize of disc = 17 (for countries)
class mlp_classifier(nn.Module):
    """ Multi-Layer Perceptron for discriminating real vs generated sequences.

    Parameters:
        inputs (tensor):Tensor of size (batch_size, vocab_size*max_seq_len) containing real or generated sequences.
        dim (int):Discriminator dimension parameter (in each middle layer).
        input_size (int):Size of the first layer (vocab_size*max_seq_len).
        num_layers (int):How many middle or hidden layers for discriminator.

    Returns:
        outputs (tensor):Batch of (single) values for real or generated inputs.   

    """
    def __init__(self, dim, input_size, num_layers=4):
        super(mlp_classifier, self).__init__()
        
        num_layers = num_layers + 2  # add 2 for the 1st and the last layers
        modules = []
        for layer in range(num_layers):
            in_size = input_size if layer == 0 else dim
            out_size = 5 if layer == num_layers - 1 else dim # if not last layer then uses dim size
            if layer < num_layers - 1:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                        nn.LeakyReLU(True),
                    )
                )
            else:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                    )
                )
        self.layers = nn.Sequential(*modules)
        
    def forward(self, inputs):
        inputs = inputs.view(inputs.size(0), -1)
        outputs = self.layers(inputs)
        return outputs

# %%
   
class resblock_2d(nn.Module):
    """Class to return a block of 2D Resudual Networks
    
    Parameters:
        inputs (tensor):Input of the previous layer
        num_channels (int):Dimension parameter (in each resnet block).
        network (str):Network of interest? 'discriminator' or 'generator' (slight 'relu' differentce in the results)
        kernel_size (tuple):Size of the (2D) filters (or kernels).

    Returns:
        outputs (torch.nn.Module):'resblock_2d' module that consist of several "conv2d->BN->relu" repetitions
    
    """
    def __init__(self, num_channels, network, kernel_size=(5, 3)):
        super(resblock_2d, self).__init__()
        modules = []
        if network=="generator":
            relu = nn.ReLU(True)
        elif network=="discriminator":
            relu = nn.ReLU(True)
        for r in range(2):
            modules.append(
                nn.Sequential(
                    nn.Conv2d(num_channels, num_channels, kernel_size, stride=(1, 1), 
                              padding=(kernel_size[0]//2, kernel_size[1]//2)),  # bottleneck: (batch, width, out_chan)
                    nn.BatchNorm2d(num_channels),
                    relu
                )
            )
        self.block = nn.Sequential(*modules)
        
    def forward(self, inputs):
        outputs = self.block(inputs)
        return outputs
    
class resnet_classifier_2d(nn.Module):
    """ Resudual Network with 2D convolutions for discriminating real vs generated sequences.

    Parameters:
        inputs (tensor):Tensor of size (batch_size, vocab_size, max_seq_len) containing real or generated sequences.
        num_channels (int):Discriminator dimension parameter (in each resnet block).
        vocab_size (int):Size of the first layer input channel.
        seq_len (int):Length of the input sequence.
        num_layers (int):How many repetitions of 'resblock_2d' for discriminator.

    Returns:
        outputs (tensor):Batch of 2D tensors of values in the size (vocab_size, seq_len).   

    """
    def __init__(self, num_channels, vocab_size, seq_len, res_layers=5):
        super(resnet_classifier_2d, self).__init__()
        
        self.num_channels = num_channels
        self.vocab_size = vocab_size
        self.seq_len = seq_len
        self.res_layers = res_layers
                
        self.conv = nn.Sequential(
                nn.Conv2d(1, num_channels, (3, 1), stride=(1, 1), padding=(3//2, 0))  # (batch, width, out_chan)
            )
        resblocks = []
        for i in range(res_layers):
            resblocks.append(resblock_2d(self.num_channels, "discriminator"))
        self.resblocks = nn.Sequential(*resblocks)
        self.prediction_layer = nn.Linear(self.vocab_size*seq_len*num_channels, 5)
            
    def forward(self, inputs):
        inputs = torch.reshape(inputs, [-1, 1, self.vocab_size, self.seq_len])
        outputs = self.conv(inputs)
        inputs = outputs
        for i in range(self.res_layers):
            outputs = 1.0*self.resblocks[i](inputs) + inputs  # where resnet idea comes into play!
            inputs = outputs
        outputs = torch.reshape(outputs, [-1, self.vocab_size*self.seq_len*self.num_channels])
        
        outputs = self.prediction_layer(outputs)
        return outputs

# %% [markdown]
# # Criterion + Optimizer:

# %%
vocab_size = 5# instantiate models
if args.model_type=="mlp":
   # netC = mlp_classifier(args.gen_dim, args.latent_dim, args.seq_len*args.vocab_size, args.gen_layers).to(device)
  #  netD = mlp_discriminator(args.disc_dim, args.seq_len*vocab_size, args.disc_layers).to(device) #fix max_seq_len
    model = mlp_classifier(args.disc_dim, args.seq_len*vocab_size, args.disc_layers).to(device)
if args.model_type=="resnet2d":
    model = resnet_classifier_2d(args.disc_dim, vocab_size, args.seq_len, args.disc_layers).to(device)
print("test")
print("{}\nClassifier Network Architecture:\n{}\n{}\n".format("="*31, "~"*31, model))
# print("{}\nDiscriminator Network Architecture:\n{}\n{}\n".format("="*35, "~"*35, netD))

# cost function (for discriminator prediction)
# criterion = nn.BCEWithLogitsLoss() # use CE loss for classifier
criterion = nn.CrossEntropyLoss()

# setup optimizer
# optimizerG = optim.Adam(list(netG.parameters()), lr=args.learning_rate)
# optimizerD = optim.Adam(list(netD.parameters()), lr=args.learning_rate)
optimizerM = optim.Adam(list(model.parameters()), lr=args.learning_rate, betas=(args.beta1, 0.999))
# Out:
# test
# ===============================
# Classifier Network Architecture:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# mlp_classifier(
#   (layers): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=19915, out_features=16, bias=True)
#       (1): LeakyReLU(negative_slope=True)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=16, out_features=16, bias=True)
#       (1): LeakyReLU(negative_slope=True)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=16, out_features=5, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Training Loop + Metrics:

# %%
es = EarlyStopping(patience=5)
epochs = args.nb_epochs
steps = 0
running_loss = 0
print_every = 10
train_losses, validation_losses = [], []
train_accuracies, valid_accuracies = [], []
for epoch in range(epochs):
    correct = 0
    total = 0
    for inputs, labels in dataloader_train:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizerM.zero_grad()
        logps = model.forward(inputs.float())
        #print(logps.shape)
        loss = criterion(logps, torch.argmax(labels, 1))
        loss.backward()
        optimizerM.step()
        running_loss += loss.item()*inputs.shape[0]
        for pred, true in zip(torch.argmax(logps, 1), torch.argmax(labels, 1)):
            if pred == true: correct += 1
            total += 1

    train_accuracy = np.round((correct/total)*100, 3) 

    #if steps % print_every == 0:
    validation_loss = 0
    accuracy = 0
    MAX_VAL=0
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in dataloader_validation:
            inputs, labels = inputs.to(device), labels.to(device)
            logps = model.forward(inputs.float())
            #print(logps)
            batch_loss = criterion(logps, torch.argmax(labels, 1))
            validation_loss += batch_loss.item()*inputs.shape[0]

            for pred, true in zip(torch.argmax(logps, 1), torch.argmax(labels, 1)):
                if pred == true: correct += 1
                total += 1
        validation_accuracy = np.round((correct/total)*100, 3)


        train_losses.append(running_loss/len(dataset_train))
        validation_losses.append(validation_loss/len(dataset_validation))
        train_accuracies.append(train_accuracy)
        valid_accuracies.append(validation_accuracy)   
        

                           
        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train loss: {running_loss/len(dataset_train):.5f} | "
              f"validation loss: {validation_loss/len(dataset_validation):.5f} | "
              f"train accuracy: {train_accuracy}% | " 
              f"validation accuracy: {validation_accuracy}%")
        running_loss = 0
        model.train()
#        metric = eval(model, dataloader_test)
#        if es.step(metric):
#                break  # early stop criterion is met, we can stop now
torch.save(model.state_dict(), "/content/drive/MyDrive/classifier_test.pth")
# Out:
# Epoch 1/500 | Train loss: 1.01177 | validation loss: 0.90738 | train accuracy: 70.814% | validation accuracy: 69.863%
# Epoch 2/500 | Train loss: 0.84846 | validation loss: 0.84369 | train accuracy: 70.976% | validation accuracy: 69.863%
# Epoch 3/500 | Train loss: 0.79995 | validation loss: 0.80718 | train accuracy: 71.02% | validation accuracy: 70.217%
# Epoch 4/500 | Train loss: 0.76636 | validation loss: 0.77653 | train accuracy: 71.742% | validation accuracy: 71.233%
# Epoch 5/500 | Train loss: 0.74086 | validation loss: 0.75327 | train accuracy: 72.759% | validation accuracy: 72.647%
# Epoch 6/500 | Train loss: 0.71898 | validation loss: 0.73390 | train accuracy: 74.086% | validation accuracy: 73.177%
# Epoch 7/500 | Train loss: 0.70186 | validation loss: 0.72043 | train accuracy: 75.118% | validation accuracy: 73.752%
# Epoch 8/500 | Train loss: 0.68686 | validation loss: 0.70426 | train accuracy: 75.914% | validation accuracy: 75.033%
# Epoch 9/500 | Train loss: 0.67408 | validation loss: 0.69623 | train accuracy: 76.474% | validation accuracy: 75.254%
# Epoch 10/500 | Train loss: 0.66298 | validation loss: 0.68222 | train accuracy: 76.666% | validation accuracy: 75.917%
# Epoch 11/500 | Train loss: 0.65262 | validation loss: 0.67426 | train accuracy: 76.828% | validation accuracy: 76.315%
# Epoch 12/500 | Train loss: 0.64368 | validation loss: 0.66416 | train accuracy: 77.034% | validation accuracy: 76.094%
# Epoch 13/500 | Train loss: 0.63549 | validation loss: 0.65667 | train accuracy: 77.167% | validation accuracy: 76.491%
# Epoch 14/500 | Train loss: 0.62695 | validation loss: 0.64959 | train accuracy: 77.594% | validation accuracy: 76.845%
# Epoch 15/500 | Train loss: 0.62104 | validation loss: 0.64511 | train accuracy: 77.904% | validation accuracy: 76.889%
# Epoch 16/500 | Train loss: 0.61499 | validation loss: 0.63736 | train accuracy: 78.096% | validation accuracy: 77.11%
# Epoch 17/500 | Train loss: 0.60824 | validation loss: 0.63500 | train accuracy: 78.42% | validation accuracy: 77.464%
# Epoch 18/500 | Train loss: 0.60360 | validation loss: 0.62602 | train accuracy: 78.641% | validation accuracy: 77.375%
# Epoch 19/500 | Train loss: 0.59746 | validation loss: 0.62410 | train accuracy: 78.936% | validation accuracy: 77.64%
# Epoch 20/500 | Train loss: 0.59345 | validation loss: 0.61625 | train accuracy: 78.995% | validation accuracy: 77.817%
# Epoch 21/500 | Train loss: 0.58752 | validation loss: 0.61469 | train accuracy: 79.496% | validation accuracy: 78.126%
# Epoch 22/500 | Train loss: 0.58402 | validation loss: 0.60863 | train accuracy: 79.496% | validation accuracy: 77.243%
# Epoch 23/500 | Train loss: 0.57953 | validation loss: 0.60388 | train accuracy: 79.658% | validation accuracy: 77.773%
# Epoch 24/500 | Train loss: 0.57568 | validation loss: 0.59951 | train accuracy: 79.673% | validation accuracy: 77.994%
# Epoch 25/500 | Train loss: 0.57178 | validation loss: 0.59731 | train accuracy: 79.879% | validation accuracy: 78.789%
# Epoch 26/500 | Train loss: 0.56781 | validation loss: 0.59232 | train accuracy: 79.894% | validation accuracy: 79.143%
# Epoch 27/500 | Train loss: 0.56368 | validation loss: 0.59250 | train accuracy: 80.115% | validation accuracy: 78.612%
# Epoch 28/500 | Train loss: 0.56132 | validation loss: 0.58681 | train accuracy: 79.953% | validation accuracy: 79.01%
# Epoch 29/500 | Train loss: 0.55790 | validation loss: 0.58334 | train accuracy: 80.38% | validation accuracy: 78.215%
# Epoch 30/500 | Train loss: 0.55432 | validation loss: 0.57990 | train accuracy: 80.071% | validation accuracy: 79.01%
# Epoch 31/500 | Train loss: 0.55138 | validation loss: 0.57583 | train accuracy: 80.262% | validation accuracy: 79.231%
# Epoch 32/500 | Train loss: 0.54822 | validation loss: 0.57279 | train accuracy: 80.469% | validation accuracy: 79.452%
# Epoch 33/500 | Train loss: 0.54547 | validation loss: 0.57185 | train accuracy: 80.557% | validation accuracy: 78.833%
# Epoch 34/500 | Train loss: 0.54270 | validation loss: 0.56877 | train accuracy: 80.542% | validation accuracy: 78.745%
# Epoch 35/500 | Train loss: 0.53945 | validation loss: 0.56598 | train accuracy: 80.498% | validation accuracy: 78.701%
# Epoch 36/500 | Train loss: 0.53685 | validation loss: 0.56321 | train accuracy: 80.439% | validation accuracy: 79.187%
# Epoch 37/500 | Train loss: 0.53426 | validation loss: 0.56114 | train accuracy: 80.587% | validation accuracy: 79.452%
# Epoch 38/500 | Train loss: 0.53153 | validation loss: 0.55697 | train accuracy: 80.705% | validation accuracy: 79.761%
# Epoch 39/500 | Train loss: 0.52966 | validation loss: 0.55547 | train accuracy: 80.896% | validation accuracy: 79.673%
# Epoch 40/500 | Train loss: 0.52724 | validation loss: 0.55345 | train accuracy: 80.867% | validation accuracy: 79.717%
# Epoch 41/500 | Train loss: 0.52380 | validation loss: 0.55140 | train accuracy: 80.985% | validation accuracy: 79.408%
# Epoch 42/500 | Train loss: 0.52212 | validation loss: 0.54923 | train accuracy: 80.837% | validation accuracy: 79.585%
# Epoch 43/500 | Train loss: 0.51851 | validation loss: 0.54733 | train accuracy: 80.999% | validation accuracy: 79.408%
# Epoch 44/500 | Train loss: 0.51733 | validation loss: 0.54599 | train accuracy: 80.97% | validation accuracy: 79.761%
# Epoch 45/500 | Train loss: 0.51446 | validation loss: 0.54136 | train accuracy: 81.029% | validation accuracy: 80.115%
# Epoch 46/500 | Train loss: 0.51261 | validation loss: 0.53962 | train accuracy: 81.176% | validation accuracy: 79.761%
# Epoch 47/500 | Train loss: 0.51065 | validation loss: 0.53861 | train accuracy: 81.132% | validation accuracy: 79.673%
# Epoch 48/500 | Train loss: 0.50920 | validation loss: 0.53780 | train accuracy: 81.058% | validation accuracy: 79.894%
# Epoch 49/500 | Train loss: 0.50609 | validation loss: 0.53419 | train accuracy: 81.147% | validation accuracy: 79.761%
# Epoch 50/500 | Train loss: 0.50440 | validation loss: 0.53236 | train accuracy: 81.073% | validation accuracy: 80.027%
# Epoch 51/500 | Train loss: 0.50225 | validation loss: 0.53017 | train accuracy: 81.176% | validation accuracy: 79.85%
# Epoch 52/500 | Train loss: 0.50051 | validation loss: 0.52948 | train accuracy: 81.25% | validation accuracy: 79.938%
# Epoch 53/500 | Train loss: 0.49811 | validation loss: 0.52757 | train accuracy: 81.206% | validation accuracy: 80.292%
# Epoch 54/500 | Train loss: 0.49663 | validation loss: 0.52497 | train accuracy: 81.353% | validation accuracy: 80.071%
# Epoch 55/500 | Train loss: 0.49519 | validation loss: 0.52407 | train accuracy: 81.412% | validation accuracy: 79.894%
# Epoch 56/500 | Train loss: 0.49285 | validation loss: 0.52233 | train accuracy: 81.338% | validation accuracy: 80.336%
# Epoch 57/500 | Train loss: 0.49032 | validation loss: 0.52086 | train accuracy: 81.604% | validation accuracy: 79.982%
# Epoch 58/500 | Train loss: 0.48938 | validation loss: 0.51885 | train accuracy: 81.515% | validation accuracy: 80.071%
# Epoch 59/500 | Train loss: 0.48733 | validation loss: 0.51742 | train accuracy: 81.515% | validation accuracy: 80.38%
# Epoch 60/500 | Train loss: 0.48494 | validation loss: 0.51980 | train accuracy: 81.663% | validation accuracy: 80.336%
# Epoch 61/500 | Train loss: 0.48395 | validation loss: 0.51360 | train accuracy: 81.854% | validation accuracy: 80.601%
# Epoch 62/500 | Train loss: 0.48132 | validation loss: 0.51178 | train accuracy: 81.619% | validation accuracy: 80.513%
# Epoch 63/500 | Train loss: 0.47991 | validation loss: 0.51031 | train accuracy: 81.707% | validation accuracy: 80.513%
# Epoch 64/500 | Train loss: 0.47842 | validation loss: 0.50898 | train accuracy: 81.781% | validation accuracy: 80.689%
# Epoch 65/500 | Train loss: 0.47701 | validation loss: 0.50812 | train accuracy: 81.795% | validation accuracy: 80.468%
# Epoch 66/500 | Train loss: 0.47471 | validation loss: 0.50707 | train accuracy: 81.854% | validation accuracy: 80.778%
# Epoch 67/500 | Train loss: 0.47317 | validation loss: 0.50614 | train accuracy: 81.825% | validation accuracy: 80.336%
# Epoch 68/500 | Train loss: 0.47162 | validation loss: 0.50445 | train accuracy: 82.075% | validation accuracy: 80.822%
# Epoch 69/500 | Train loss: 0.47077 | validation loss: 0.50211 | train accuracy: 81.958% | validation accuracy: 80.866%
# Epoch 70/500 | Train loss: 0.46875 | validation loss: 0.50080 | train accuracy: 81.899% | validation accuracy: 80.91%
# Epoch 71/500 | Train loss: 0.46672 | validation loss: 0.50545 | train accuracy: 82.075% | validation accuracy: 79.806%
# Epoch 72/500 | Train loss: 0.46590 | validation loss: 0.50031 | train accuracy: 82.179% | validation accuracy: 80.557%
# Epoch 73/500 | Train loss: 0.46372 | validation loss: 0.49673 | train accuracy: 82.193% | validation accuracy: 81.043%
# Epoch 74/500 | Train loss: 0.46277 | validation loss: 0.49545 | train accuracy: 82.164% | validation accuracy: 81.308%
# Epoch 75/500 | Train loss: 0.46123 | validation loss: 0.49412 | train accuracy: 82.297% | validation accuracy: 81.264%
# Epoch 76/500 | Train loss: 0.45966 | validation loss: 0.49293 | train accuracy: 82.267% | validation accuracy: 81.131%
# Epoch 77/500 | Train loss: 0.45811 | validation loss: 0.49597 | train accuracy: 82.267% | validation accuracy: 80.424%
# Epoch 78/500 | Train loss: 0.45657 | validation loss: 0.49057 | train accuracy: 82.429% | validation accuracy: 81.22%
# Epoch 79/500 | Train loss: 0.45456 | validation loss: 0.48994 | train accuracy: 82.356% | validation accuracy: 80.954%
# Epoch 80/500 | Train loss: 0.45344 | validation loss: 0.48932 | train accuracy: 82.488% | validation accuracy: 81.264%
# Epoch 81/500 | Train loss: 0.45065 | validation loss: 0.48692 | train accuracy: 82.488% | validation accuracy: 81.22%
# Epoch 82/500 | Train loss: 0.45097 | validation loss: 0.48684 | train accuracy: 82.577% | validation accuracy: 80.689%
# Epoch 83/500 | Train loss: 0.44985 | validation loss: 0.48794 | train accuracy: 82.518% | validation accuracy: 81.264%
# Epoch 84/500 | Train loss: 0.44788 | validation loss: 0.48742 | train accuracy: 82.518% | validation accuracy: 81.22%
# Epoch 85/500 | Train loss: 0.44698 | validation loss: 0.48256 | train accuracy: 82.562% | validation accuracy: 81.617%
# Epoch 86/500 | Train loss: 0.44640 | validation loss: 0.48111 | train accuracy: 82.709% | validation accuracy: 81.838%
# Epoch 87/500 | Train loss: 0.44398 | validation loss: 0.48117 | train accuracy: 82.709% | validation accuracy: 81.396%
# Epoch 88/500 | Train loss: 0.44353 | validation loss: 0.47963 | train accuracy: 82.606% | validation accuracy: 81.529%
# Epoch 89/500 | Train loss: 0.44128 | validation loss: 0.48117 | train accuracy: 82.812% | validation accuracy: 80.91%
# Epoch 90/500 | Train loss: 0.44067 | validation loss: 0.47739 | train accuracy: 82.724% | validation accuracy: 81.75%
# Epoch 91/500 | Train loss: 0.43913 | validation loss: 0.47981 | train accuracy: 82.842% | validation accuracy: 81.529%
# Epoch 92/500 | Train loss: 0.43799 | validation loss: 0.47499 | train accuracy: 82.886% | validation accuracy: 81.794%
# Epoch 93/500 | Train loss: 0.43599 | validation loss: 0.47427 | train accuracy: 82.871% | validation accuracy: 81.882%
# Epoch 94/500 | Train loss: 0.43544 | validation loss: 0.47375 | train accuracy: 83.019% | validation accuracy: 81.838%
# Epoch 95/500 | Train loss: 0.43395 | validation loss: 0.47184 | train accuracy: 82.901% | validation accuracy: 82.148%
# Epoch 96/500 | Train loss: 0.43247 | validation loss: 0.47250 | train accuracy: 83.004% | validation accuracy: 81.706%
# Epoch 97/500 | Train loss: 0.43110 | validation loss: 0.47016 | train accuracy: 82.989% | validation accuracy: 82.059%
# Epoch 98/500 | Train loss: 0.43060 | validation loss: 0.47097 | train accuracy: 83.21% | validation accuracy: 82.103%
# Epoch 99/500 | Train loss: 0.42943 | validation loss: 0.46980 | train accuracy: 83.225% | validation accuracy: 81.75%
# Epoch 100/500 | Train loss: 0.42770 | validation loss: 0.46932 | train accuracy: 83.137% | validation accuracy: 81.75%
# Epoch 101/500 | Train loss: 0.42660 | validation loss: 0.46983 | train accuracy: 83.328% | validation accuracy: 81.706%
# Epoch 102/500 | Train loss: 0.42566 | validation loss: 0.46594 | train accuracy: 83.387% | validation accuracy: 82.103%
# Epoch 103/500 | Train loss: 0.42393 | validation loss: 0.46464 | train accuracy: 83.225% | validation accuracy: 82.192%
# Epoch 104/500 | Train loss: 0.42437 | validation loss: 0.46478 | train accuracy: 83.328% | validation accuracy: 82.015%
# Epoch 105/500 | Train loss: 0.42219 | validation loss: 0.46545 | train accuracy: 83.269% | validation accuracy: 81.573%
# Epoch 106/500 | Train loss: 0.42127 | validation loss: 0.46493 | train accuracy: 83.284% | validation accuracy: 81.927%
# Epoch 107/500 | Train loss: 0.42027 | validation loss: 0.46623 | train accuracy: 83.402% | validation accuracy: 81.838%
# Epoch 108/500 | Train loss: 0.41884 | validation loss: 0.46024 | train accuracy: 83.387% | validation accuracy: 82.236%
# Epoch 109/500 | Train loss: 0.41785 | validation loss: 0.45911 | train accuracy: 83.55% | validation accuracy: 82.103%
# Epoch 110/500 | Train loss: 0.41627 | validation loss: 0.46132 | train accuracy: 83.535% | validation accuracy: 82.103%
# Epoch 111/500 | Train loss: 0.41490 | validation loss: 0.45779 | train accuracy: 83.461% | validation accuracy: 82.413%
# Epoch 112/500 | Train loss: 0.41438 | validation loss: 0.45669 | train accuracy: 83.608% | validation accuracy: 82.324%
# Epoch 113/500 | Train loss: 0.41388 | validation loss: 0.45619 | train accuracy: 83.653% | validation accuracy: 82.192%
# Epoch 114/500 | Train loss: 0.41227 | validation loss: 0.45640 | train accuracy: 83.505% | validation accuracy: 82.28%
# Epoch 115/500 | Train loss: 0.41159 | validation loss: 0.45544 | train accuracy: 83.461% | validation accuracy: 82.28%
# Epoch 116/500 | Train loss: 0.40949 | validation loss: 0.45902 | train accuracy: 83.55% | validation accuracy: 81.838%
# Epoch 117/500 | Train loss: 0.40912 | validation loss: 0.45253 | train accuracy: 83.623% | validation accuracy: 82.369%
# Epoch 118/500 | Train loss: 0.40802 | validation loss: 0.45328 | train accuracy: 83.623% | validation accuracy: 82.501%
# Epoch 119/500 | Train loss: 0.40685 | validation loss: 0.45365 | train accuracy: 83.741% | validation accuracy: 82.324%
# Epoch 120/500 | Train loss: 0.40648 | validation loss: 0.45096 | train accuracy: 83.579% | validation accuracy: 82.369%
# Epoch 121/500 | Train loss: 0.40577 | validation loss: 0.44972 | train accuracy: 83.785% | validation accuracy: 82.457%
# Epoch 122/500 | Train loss: 0.40460 | validation loss: 0.45287 | train accuracy: 83.697% | validation accuracy: 82.545%
# Epoch 123/500 | Train loss: 0.40384 | validation loss: 0.44805 | train accuracy: 83.785% | validation accuracy: 82.634%
# Epoch 124/500 | Train loss: 0.40201 | validation loss: 0.44806 | train accuracy: 83.8% | validation accuracy: 82.589%
# Epoch 125/500 | Train loss: 0.40085 | validation loss: 0.44769 | train accuracy: 83.83% | validation accuracy: 82.501%
# Epoch 126/500 | Train loss: 0.40056 | validation loss: 0.44659 | train accuracy: 83.962% | validation accuracy: 82.545%
# Epoch 127/500 | Train loss: 0.39888 | validation loss: 0.44565 | train accuracy: 83.903% | validation accuracy: 82.413%
# Epoch 128/500 | Train loss: 0.39851 | validation loss: 0.44505 | train accuracy: 83.815% | validation accuracy: 82.545%
# Epoch 129/500 | Train loss: 0.39726 | validation loss: 0.44385 | train accuracy: 84.198% | validation accuracy: 82.678%
# Epoch 130/500 | Train loss: 0.39660 | validation loss: 0.44507 | train accuracy: 83.992% | validation accuracy: 82.722%
# Epoch 131/500 | Train loss: 0.39620 | validation loss: 0.44284 | train accuracy: 83.859% | validation accuracy: 82.766%
# Epoch 132/500 | Train loss: 0.39444 | validation loss: 0.44210 | train accuracy: 84.08% | validation accuracy: 82.678%
# Epoch 133/500 | Train loss: 0.39407 | validation loss: 0.44116 | train accuracy: 83.992% | validation accuracy: 82.766%
# Epoch 134/500 | Train loss: 0.39334 | validation loss: 0.44100 | train accuracy: 84.139% | validation accuracy: 82.589%
# Epoch 135/500 | Train loss: 0.39196 | validation loss: 0.44289 | train accuracy: 84.198% | validation accuracy: 82.634%
# Epoch 136/500 | Train loss: 0.39170 | validation loss: 0.43955 | train accuracy: 84.095% | validation accuracy: 82.545%
# Epoch 137/500 | Train loss: 0.39073 | validation loss: 0.44003 | train accuracy: 84.095% | validation accuracy: 82.634%
# Epoch 138/500 | Train loss: 0.38904 | validation loss: 0.44037 | train accuracy: 84.331% | validation accuracy: 82.28%
# Epoch 139/500 | Train loss: 0.38859 | validation loss: 0.43970 | train accuracy: 84.228% | validation accuracy: 82.589%
# Epoch 140/500 | Train loss: 0.38681 | validation loss: 0.43929 | train accuracy: 84.626% | validation accuracy: 82.634%
# Epoch 141/500 | Train loss: 0.38617 | validation loss: 0.43674 | train accuracy: 84.213% | validation accuracy: 82.545%
# Epoch 142/500 | Train loss: 0.38590 | validation loss: 0.43700 | train accuracy: 84.331% | validation accuracy: 82.589%
# Epoch 143/500 | Train loss: 0.38642 | validation loss: 0.43643 | train accuracy: 84.287% | validation accuracy: 82.589%
# Epoch 144/500 | Train loss: 0.38486 | validation loss: 0.43527 | train accuracy: 84.346% | validation accuracy: 82.722%
# Epoch 145/500 | Train loss: 0.38344 | validation loss: 0.43401 | train accuracy: 84.463% | validation accuracy: 83.164%
# Epoch 146/500 | Train loss: 0.38260 | validation loss: 0.43399 | train accuracy: 84.419% | validation accuracy: 82.722%
# Epoch 147/500 | Train loss: 0.38195 | validation loss: 0.43353 | train accuracy: 84.552% | validation accuracy: 82.855%
# Epoch 148/500 | Train loss: 0.38107 | validation loss: 0.43209 | train accuracy: 84.493% | validation accuracy: 82.899%
# Epoch 149/500 | Train loss: 0.37972 | validation loss: 0.43278 | train accuracy: 84.67% | validation accuracy: 82.899%
# Epoch 150/500 | Train loss: 0.37982 | validation loss: 0.43295 | train accuracy: 84.626% | validation accuracy: 82.678%
# Epoch 151/500 | Train loss: 0.37895 | validation loss: 0.43196 | train accuracy: 84.567% | validation accuracy: 82.678%
# Epoch 152/500 | Train loss: 0.37853 | validation loss: 0.43133 | train accuracy: 84.758% | validation accuracy: 82.81%
# Epoch 153/500 | Train loss: 0.37683 | validation loss: 0.42948 | train accuracy: 84.729% | validation accuracy: 82.987%
# Epoch 154/500 | Train loss: 0.37615 | validation loss: 0.43005 | train accuracy: 84.611% | validation accuracy: 82.855%
# Epoch 155/500 | Train loss: 0.37475 | validation loss: 0.42959 | train accuracy: 84.802% | validation accuracy: 83.429%
# Epoch 156/500 | Train loss: 0.37562 | validation loss: 0.42936 | train accuracy: 84.861% | validation accuracy: 82.943%
# Epoch 157/500 | Train loss: 0.37448 | validation loss: 0.42776 | train accuracy: 84.876% | validation accuracy: 82.987%
# Epoch 158/500 | Train loss: 0.37401 | validation loss: 0.42740 | train accuracy: 84.788% | validation accuracy: 83.031%
# Epoch 159/500 | Train loss: 0.37262 | validation loss: 0.42653 | train accuracy: 84.685% | validation accuracy: 83.031%
# Epoch 160/500 | Train loss: 0.37203 | validation loss: 0.43067 | train accuracy: 84.979% | validation accuracy: 82.766%
# Epoch 161/500 | Train loss: 0.37127 | validation loss: 0.42566 | train accuracy: 84.906% | validation accuracy: 83.076%
# Epoch 162/500 | Train loss: 0.37138 | validation loss: 0.42500 | train accuracy: 84.832% | validation accuracy: 83.164%
# Epoch 163/500 | Train loss: 0.36916 | validation loss: 0.42836 | train accuracy: 85.112% | validation accuracy: 82.678%
# Epoch 164/500 | Train loss: 0.36951 | validation loss: 0.42509 | train accuracy: 85.097% | validation accuracy: 83.208%
# Epoch 165/500 | Train loss: 0.36870 | validation loss: 0.42430 | train accuracy: 85.024% | validation accuracy: 82.987%
# Epoch 166/500 | Train loss: 0.36710 | validation loss: 0.42346 | train accuracy: 85.142% | validation accuracy: 83.297%
# Epoch 167/500 | Train loss: 0.36674 | validation loss: 0.43202 | train accuracy: 85.068% | validation accuracy: 82.766%
# Epoch 168/500 | Train loss: 0.36597 | validation loss: 0.42812 | train accuracy: 85.392% | validation accuracy: 82.678%
# Epoch 169/500 | Train loss: 0.36524 | validation loss: 0.42144 | train accuracy: 85.23% | validation accuracy: 83.429%
# Epoch 170/500 | Train loss: 0.36421 | validation loss: 0.42375 | train accuracy: 85.245% | validation accuracy: 85.462%
# Epoch 171/500 | Train loss: 0.36521 | validation loss: 0.42079 | train accuracy: 85.304% | validation accuracy: 83.429%
# Epoch 172/500 | Train loss: 0.36376 | validation loss: 0.42089 | train accuracy: 85.348% | validation accuracy: 83.297%
# Epoch 173/500 | Train loss: 0.36310 | validation loss: 0.42021 | train accuracy: 85.333% | validation accuracy: 83.341%
# Epoch 174/500 | Train loss: 0.36166 | validation loss: 0.42128 | train accuracy: 85.289% | validation accuracy: 85.506%
# Epoch 175/500 | Train loss: 0.36194 | validation loss: 0.42145 | train accuracy: 85.584% | validation accuracy: 82.943%
# Epoch 176/500 | Train loss: 0.36041 | validation loss: 0.41916 | train accuracy: 85.466% | validation accuracy: 83.562%
# Epoch 177/500 | Train loss: 0.36012 | validation loss: 0.42039 | train accuracy: 85.775% | validation accuracy: 83.164%
# Epoch 178/500 | Train loss: 0.35872 | validation loss: 0.42128 | train accuracy: 85.598% | validation accuracy: 85.064%
# Epoch 179/500 | Train loss: 0.35981 | validation loss: 0.42094 | train accuracy: 85.407% | validation accuracy: 83.076%
# Epoch 180/500 | Train loss: 0.35775 | validation loss: 0.41644 | train accuracy: 85.466% | validation accuracy: 83.694%
# Epoch 181/500 | Train loss: 0.35763 | validation loss: 0.41724 | train accuracy: 85.672% | validation accuracy: 83.429%
# Epoch 182/500 | Train loss: 0.35766 | validation loss: 0.41982 | train accuracy: 85.598% | validation accuracy: 83.031%
# Epoch 183/500 | Train loss: 0.35576 | validation loss: 0.41848 | train accuracy: 85.761% | validation accuracy: 83.164%
# Epoch 184/500 | Train loss: 0.35552 | validation loss: 0.43160 | train accuracy: 85.54% | validation accuracy: 84.401%
# Epoch 185/500 | Train loss: 0.35593 | validation loss: 0.41525 | train accuracy: 85.938% | validation accuracy: 83.606%
# Epoch 186/500 | Train loss: 0.35370 | validation loss: 0.41603 | train accuracy: 85.82% | validation accuracy: 83.517%
# Epoch 187/500 | Train loss: 0.35455 | validation loss: 0.41366 | train accuracy: 86.041% | validation accuracy: 83.827%
# Epoch 188/500 | Train loss: 0.35327 | validation loss: 0.41704 | train accuracy: 85.761% | validation accuracy: 83.164%
# Epoch 189/500 | Train loss: 0.35327 | validation loss: 0.41348 | train accuracy: 85.746% | validation accuracy: 84.048%
# Epoch 190/500 | Train loss: 0.35165 | validation loss: 0.41240 | train accuracy: 85.864% | validation accuracy: 84.18%
# Epoch 191/500 | Train loss: 0.35196 | validation loss: 0.41533 | train accuracy: 85.952% | validation accuracy: 83.252%
# Epoch 192/500 | Train loss: 0.35101 | validation loss: 0.41212 | train accuracy: 85.967% | validation accuracy: 83.562%
# Epoch 193/500 | Train loss: 0.35085 | validation loss: 0.41184 | train accuracy: 85.82% | validation accuracy: 83.871%
# Epoch 194/500 | Train loss: 0.35027 | validation loss: 0.41255 | train accuracy: 86.114% | validation accuracy: 83.65%
# Epoch 195/500 | Train loss: 0.34942 | validation loss: 0.41162 | train accuracy: 86.055% | validation accuracy: 83.606%
# Epoch 196/500 | Train loss: 0.34906 | validation loss: 0.41235 | train accuracy: 86.159% | validation accuracy: 83.473%
# Epoch 197/500 | Train loss: 0.34709 | validation loss: 0.41278 | train accuracy: 86.144% | validation accuracy: 83.65%
# Epoch 198/500 | Train loss: 0.34744 | validation loss: 0.41582 | train accuracy: 86.277% | validation accuracy: 83.208%
# Epoch 199/500 | Train loss: 0.34628 | validation loss: 0.41082 | train accuracy: 86.218% | validation accuracy: 83.959%
# Epoch 200/500 | Train loss: 0.34585 | validation loss: 0.40966 | train accuracy: 86.203% | validation accuracy: 83.738%
# Epoch 201/500 | Train loss: 0.34591 | validation loss: 0.40964 | train accuracy: 86.218% | validation accuracy: 83.783%
# Epoch 202/500 | Train loss: 0.34562 | validation loss: 0.41431 | train accuracy: 86.468% | validation accuracy: 83.385%
# Epoch 203/500 | Train loss: 0.34362 | validation loss: 0.40771 | train accuracy: 86.35% | validation accuracy: 84.269%
# Epoch 204/500 | Train loss: 0.34381 | validation loss: 0.40752 | train accuracy: 86.424% | validation accuracy: 84.18%
# Epoch 205/500 | Train loss: 0.34339 | validation loss: 0.40715 | train accuracy: 86.188% | validation accuracy: 84.18%
# Epoch 206/500 | Train loss: 0.34253 | validation loss: 0.41635 | train accuracy: 86.07% | validation accuracy: 83.12%
# Epoch 207/500 | Train loss: 0.34232 | validation loss: 0.41099 | train accuracy: 86.645% | validation accuracy: 83.562%
# Epoch 208/500 | Train loss: 0.34183 | validation loss: 0.40783 | train accuracy: 86.424% | validation accuracy: 84.048%
# Epoch 209/500 | Train loss: 0.34199 | validation loss: 0.41054 | train accuracy: 86.188% | validation accuracy: 83.517%
# Epoch 210/500 | Train loss: 0.34078 | validation loss: 0.40557 | train accuracy: 86.232% | validation accuracy: 83.959%
# Epoch 211/500 | Train loss: 0.34073 | validation loss: 0.40848 | train accuracy: 86.35% | validation accuracy: 85.329%
# Epoch 212/500 | Train loss: 0.33928 | validation loss: 0.40603 | train accuracy: 86.365% | validation accuracy: 85.727%
# Epoch 213/500 | Train loss: 0.33960 | validation loss: 0.40647 | train accuracy: 86.409% | validation accuracy: 83.827%
# Epoch 214/500 | Train loss: 0.33849 | validation loss: 0.40890 | train accuracy: 86.704% | validation accuracy: 83.738%
# Epoch 215/500 | Train loss: 0.33813 | validation loss: 0.40808 | train accuracy: 86.409% | validation accuracy: 83.517%
# Epoch 216/500 | Train loss: 0.33781 | validation loss: 0.40463 | train accuracy: 86.483% | validation accuracy: 83.959%
# Epoch 217/500 | Train loss: 0.33734 | validation loss: 0.40573 | train accuracy: 86.675% | validation accuracy: 83.871%
# Epoch 218/500 | Train loss: 0.33614 | validation loss: 0.40927 | train accuracy: 86.719% | validation accuracy: 83.694%
# Epoch 219/500 | Train loss: 0.33576 | validation loss: 0.40383 | train accuracy: 86.498% | validation accuracy: 84.048%
# Epoch 220/500 | Train loss: 0.33506 | validation loss: 0.40220 | train accuracy: 86.63% | validation accuracy: 84.313%
# Epoch 221/500 | Train loss: 0.33510 | validation loss: 0.40487 | train accuracy: 86.586% | validation accuracy: 85.285%
# Epoch 222/500 | Train loss: 0.33430 | validation loss: 0.40222 | train accuracy: 86.881% | validation accuracy: 84.048%
# Epoch 223/500 | Train loss: 0.33353 | validation loss: 0.40175 | train accuracy: 86.999% | validation accuracy: 83.915%
# Epoch 224/500 | Train loss: 0.33311 | validation loss: 0.40233 | train accuracy: 86.586% | validation accuracy: 85.506%
# Epoch 225/500 | Train loss: 0.33294 | validation loss: 0.40076 | train accuracy: 87.073% | validation accuracy: 85.904%
# Epoch 226/500 | Train loss: 0.33316 | validation loss: 0.40039 | train accuracy: 86.866% | validation accuracy: 84.269%
# Epoch 227/500 | Train loss: 0.33182 | validation loss: 0.40217 | train accuracy: 86.925% | validation accuracy: 85.727%
# Epoch 228/500 | Train loss: 0.33125 | validation loss: 0.39958 | train accuracy: 87.043% | validation accuracy: 84.269%
# Epoch 229/500 | Train loss: 0.33001 | validation loss: 0.39969 | train accuracy: 86.91% | validation accuracy: 86.125%
# Epoch 230/500 | Train loss: 0.33074 | validation loss: 0.39986 | train accuracy: 86.969% | validation accuracy: 86.213%
# Epoch 231/500 | Train loss: 0.32955 | validation loss: 0.40243 | train accuracy: 87.146% | validation accuracy: 83.959%
# Epoch 232/500 | Train loss: 0.32979 | validation loss: 0.40118 | train accuracy: 87.058% | validation accuracy: 84.004%
# Epoch 233/500 | Train loss: 0.32833 | validation loss: 0.40593 | train accuracy: 86.984% | validation accuracy: 84.092%
# Epoch 234/500 | Train loss: 0.32853 | validation loss: 0.40090 | train accuracy: 87.456% | validation accuracy: 84.136%
# Epoch 235/500 | Train loss: 0.32794 | validation loss: 0.39936 | train accuracy: 87.176% | validation accuracy: 84.004%
# Epoch 236/500 | Train loss: 0.32900 | validation loss: 0.39785 | train accuracy: 86.925% | validation accuracy: 86.301%
# Epoch 237/500 | Train loss: 0.32735 | validation loss: 0.39977 | train accuracy: 87.131% | validation accuracy: 84.092%
# Epoch 238/500 | Train loss: 0.32684 | validation loss: 0.39797 | train accuracy: 87.308% | validation accuracy: 86.036%
# Epoch 239/500 | Train loss: 0.32679 | validation loss: 0.39657 | train accuracy: 87.249% | validation accuracy: 84.578%
# Epoch 240/500 | Train loss: 0.32580 | validation loss: 0.40012 | train accuracy: 86.896% | validation accuracy: 83.959%
# Epoch 241/500 | Train loss: 0.32557 | validation loss: 0.39734 | train accuracy: 87.22% | validation accuracy: 84.136%
# Epoch 242/500 | Train loss: 0.32476 | validation loss: 0.39871 | train accuracy: 87.235% | validation accuracy: 85.418%
# Epoch 243/500 | Train loss: 0.32439 | validation loss: 0.39596 | train accuracy: 87.146% | validation accuracy: 84.534%
# Epoch 244/500 | Train loss: 0.32339 | validation loss: 0.39532 | train accuracy: 87.574% | validation accuracy: 84.578%
# Epoch 245/500 | Train loss: 0.32364 | validation loss: 0.39828 | train accuracy: 87.485% | validation accuracy: 84.18%
# Epoch 246/500 | Train loss: 0.32249 | validation loss: 0.39616 | train accuracy: 87.412% | validation accuracy: 84.887%
# Epoch 247/500 | Train loss: 0.32316 | validation loss: 0.39549 | train accuracy: 87.412% | validation accuracy: 84.269%
# Epoch 248/500 | Train loss: 0.32188 | validation loss: 0.39992 | train accuracy: 87.205% | validation accuracy: 84.224%
# Epoch 249/500 | Train loss: 0.32146 | validation loss: 0.39942 | train accuracy: 87.426% | validation accuracy: 84.18%
# Epoch 250/500 | Train loss: 0.32144 | validation loss: 0.39573 | train accuracy: 87.603% | validation accuracy: 84.048%
# Epoch 251/500 | Train loss: 0.32082 | validation loss: 0.39731 | train accuracy: 87.294% | validation accuracy: 85.418%
# Epoch 252/500 | Train loss: 0.32079 | validation loss: 0.39730 | train accuracy: 87.515% | validation accuracy: 84.224%
# Epoch 253/500 | Train loss: 0.32064 | validation loss: 0.39564 | train accuracy: 87.633% | validation accuracy: 84.269%
# Epoch 254/500 | Train loss: 0.32020 | validation loss: 0.39394 | train accuracy: 87.574% | validation accuracy: 85.55%
# Epoch 255/500 | Train loss: 0.31976 | validation loss: 0.39393 | train accuracy: 87.618% | validation accuracy: 85.815%
# Epoch 256/500 | Train loss: 0.31808 | validation loss: 0.39243 | train accuracy: 87.588% | validation accuracy: 84.755%
# Epoch 257/500 | Train loss: 0.31824 | validation loss: 0.40431 | train accuracy: 87.692% | validation accuracy: 84.092%
# Epoch 258/500 | Train loss: 0.31868 | validation loss: 0.39526 | train accuracy: 87.633% | validation accuracy: 84.136%
# Epoch 259/500 | Train loss: 0.31742 | validation loss: 0.39292 | train accuracy: 87.603% | validation accuracy: 84.269%
# Epoch 260/500 | Train loss: 0.31615 | validation loss: 0.39176 | train accuracy: 87.824% | validation accuracy: 85.771%
# Epoch 261/500 | Train loss: 0.31684 | validation loss: 0.39100 | train accuracy: 87.854% | validation accuracy: 86.257%
# Epoch 262/500 | Train loss: 0.31605 | validation loss: 0.39156 | train accuracy: 87.633% | validation accuracy: 85.727%
# Epoch 263/500 | Train loss: 0.31572 | validation loss: 0.39220 | train accuracy: 87.515% | validation accuracy: 84.666%
# Epoch 264/500 | Train loss: 0.31485 | validation loss: 0.39434 | train accuracy: 87.898% | validation accuracy: 84.224%
# Epoch 265/500 | Train loss: 0.31492 | validation loss: 0.39242 | train accuracy: 87.441% | validation accuracy: 84.49%
# Epoch 266/500 | Train loss: 0.31377 | validation loss: 0.39013 | train accuracy: 87.927% | validation accuracy: 86.213%
# Epoch 267/500 | Train loss: 0.31391 | validation loss: 0.39053 | train accuracy: 87.81% | validation accuracy: 84.799%
# Epoch 268/500 | Train loss: 0.31414 | validation loss: 0.38947 | train accuracy: 87.751% | validation accuracy: 86.478%
# Epoch 269/500 | Train loss: 0.31293 | validation loss: 0.38926 | train accuracy: 87.81% | validation accuracy: 86.522%
# Epoch 270/500 | Train loss: 0.31292 | validation loss: 0.39107 | train accuracy: 87.913% | validation accuracy: 85.418%
# Epoch 271/500 | Train loss: 0.31219 | validation loss: 0.38946 | train accuracy: 87.972% | validation accuracy: 85.727%
# Epoch 272/500 | Train loss: 0.31302 | validation loss: 0.38909 | train accuracy: 87.633% | validation accuracy: 84.799%
# Epoch 273/500 | Train loss: 0.31139 | validation loss: 0.38852 | train accuracy: 87.883% | validation accuracy: 86.301%
# Epoch 274/500 | Train loss: 0.31135 | validation loss: 0.38975 | train accuracy: 88.237% | validation accuracy: 86.08%
# Epoch 275/500 | Train loss: 0.31080 | validation loss: 0.39044 | train accuracy: 87.898% | validation accuracy: 84.445%
# Epoch 276/500 | Train loss: 0.30986 | validation loss: 0.38809 | train accuracy: 88.104% | validation accuracy: 86.301%
# Epoch 277/500 | Train loss: 0.31018 | validation loss: 0.38778 | train accuracy: 87.972% | validation accuracy: 86.522%
# Epoch 278/500 | Train loss: 0.30966 | validation loss: 0.39091 | train accuracy: 88.045% | validation accuracy: 84.401%
# Epoch 279/500 | Train loss: 0.30914 | validation loss: 0.38962 | train accuracy: 88.163% | validation accuracy: 84.49%
# Epoch 280/500 | Train loss: 0.30888 | validation loss: 0.39213 | train accuracy: 87.942% | validation accuracy: 84.49%
# Epoch 281/500 | Train loss: 0.30894 | validation loss: 0.38965 | train accuracy: 88.119% | validation accuracy: 84.49%
# Epoch 282/500 | Train loss: 0.30841 | validation loss: 0.38649 | train accuracy: 87.456% | validation accuracy: 86.434%
# Epoch 283/500 | Train loss: 0.30815 | validation loss: 0.38889 | train accuracy: 88.325% | validation accuracy: 84.666%
# Epoch 284/500 | Train loss: 0.30677 | validation loss: 0.38917 | train accuracy: 88.104% | validation accuracy: 84.534%
# Epoch 285/500 | Train loss: 0.30649 | validation loss: 0.39724 | train accuracy: 88.075% | validation accuracy: 84.357%
# Epoch 286/500 | Train loss: 0.30751 | validation loss: 0.38831 | train accuracy: 87.692% | validation accuracy: 84.711%
# Epoch 287/500 | Train loss: 0.30578 | validation loss: 0.38607 | train accuracy: 88.075% | validation accuracy: 86.213%
# Epoch 288/500 | Train loss: 0.30548 | validation loss: 0.38786 | train accuracy: 88.281% | validation accuracy: 85.992%
# Epoch 289/500 | Train loss: 0.30601 | validation loss: 0.38610 | train accuracy: 88.075% | validation accuracy: 86.434%
# Epoch 290/500 | Train loss: 0.30539 | validation loss: 0.38720 | train accuracy: 88.016% | validation accuracy: 85.462%
# Epoch 291/500 | Train loss: 0.30542 | validation loss: 0.39426 | train accuracy: 88.193% | validation accuracy: 84.313%
# Epoch 292/500 | Train loss: 0.30438 | validation loss: 0.38777 | train accuracy: 88.119% | validation accuracy: 84.622%
# Epoch 293/500 | Train loss: 0.30350 | validation loss: 0.38606 | train accuracy: 88.119% | validation accuracy: 85.506%
# Epoch 294/500 | Train loss: 0.30404 | validation loss: 0.38467 | train accuracy: 88.104% | validation accuracy: 85.948%
# Epoch 295/500 | Train loss: 0.30384 | validation loss: 0.39201 | train accuracy: 88.134% | validation accuracy: 84.445%
# Epoch 296/500 | Train loss: 0.30302 | validation loss: 0.38573 | train accuracy: 88.473% | validation accuracy: 84.711%
# Epoch 297/500 | Train loss: 0.30444 | validation loss: 0.38556 | train accuracy: 88.119% | validation accuracy: 84.843%
# Epoch 298/500 | Train loss: 0.30298 | validation loss: 0.38526 | train accuracy: 88.016% | validation accuracy: 86.434%
# Epoch 299/500 | Train loss: 0.30290 | validation loss: 0.38434 | train accuracy: 87.927% | validation accuracy: 85.771%
# Epoch 300/500 | Train loss: 0.30198 | validation loss: 0.38360 | train accuracy: 88.09% | validation accuracy: 86.434%
# Epoch 301/500 | Train loss: 0.30213 | validation loss: 0.38369 | train accuracy: 87.986% | validation accuracy: 86.567%
# Epoch 302/500 | Train loss: 0.30005 | validation loss: 0.38357 | train accuracy: 88.384% | validation accuracy: 85.02%
# Epoch 303/500 | Train loss: 0.30028 | validation loss: 0.38578 | train accuracy: 88.782% | validation accuracy: 84.843%
# Epoch 304/500 | Train loss: 0.29999 | validation loss: 0.38352 | train accuracy: 88.429% | validation accuracy: 86.08%
# Epoch 305/500 | Train loss: 0.30030 | validation loss: 0.38809 | train accuracy: 88.384% | validation accuracy: 86.125%
# Epoch 306/500 | Train loss: 0.29862 | validation loss: 0.38461 | train accuracy: 88.488% | validation accuracy: 84.843%
# Epoch 307/500 | Train loss: 0.29880 | validation loss: 0.38425 | train accuracy: 88.208% | validation accuracy: 84.887%
# Epoch 308/500 | Train loss: 0.29833 | validation loss: 0.38201 | train accuracy: 88.473% | validation accuracy: 86.611%
# Epoch 309/500 | Train loss: 0.29936 | validation loss: 0.38186 | train accuracy: 88.281% | validation accuracy: 86.655%
# Epoch 310/500 | Train loss: 0.29820 | validation loss: 0.38371 | train accuracy: 88.222% | validation accuracy: 84.755%
# Epoch 311/500 | Train loss: 0.29818 | validation loss: 0.38409 | train accuracy: 88.384% | validation accuracy: 84.843%
# Epoch 312/500 | Train loss: 0.29844 | validation loss: 0.38284 | train accuracy: 87.957% | validation accuracy: 86.301%
# Epoch 313/500 | Train loss: 0.29889 | validation loss: 0.38874 | train accuracy: 88.384% | validation accuracy: 84.445%
# Epoch 314/500 | Train loss: 0.29742 | validation loss: 0.38611 | train accuracy: 88.355% | validation accuracy: 84.578%
# Epoch 315/500 | Train loss: 0.29734 | validation loss: 0.39016 | train accuracy: 88.502% | validation accuracy: 84.445%
# Epoch 316/500 | Train loss: 0.29645 | validation loss: 0.38150 | train accuracy: 88.576% | validation accuracy: 86.611%
# Epoch 317/500 | Train loss: 0.29714 | validation loss: 0.38403 | train accuracy: 88.635% | validation accuracy: 84.799%
# Epoch 318/500 | Train loss: 0.29667 | validation loss: 0.38137 | train accuracy: 88.547% | validation accuracy: 84.887%
# Epoch 319/500 | Train loss: 0.29556 | validation loss: 0.38112 | train accuracy: 88.414% | validation accuracy: 86.567%
# Epoch 320/500 | Train loss: 0.29445 | validation loss: 0.38206 | train accuracy: 88.502% | validation accuracy: 85.02%
# Epoch 321/500 | Train loss: 0.29471 | validation loss: 0.38502 | train accuracy: 88.399% | validation accuracy: 86.036%
# Epoch 322/500 | Train loss: 0.29475 | validation loss: 0.39183 | train accuracy: 88.37% | validation accuracy: 85.418%
# Epoch 323/500 | Train loss: 0.29521 | validation loss: 0.38909 | train accuracy: 88.399% | validation accuracy: 84.578%
# Epoch 324/500 | Train loss: 0.29454 | validation loss: 0.38028 | train accuracy: 88.488% | validation accuracy: 86.346%
# Epoch 325/500 | Train loss: 0.29470 | validation loss: 0.38150 | train accuracy: 88.959% | validation accuracy: 84.799%
# Epoch 326/500 | Train loss: 0.29220 | validation loss: 0.38023 | train accuracy: 88.753% | validation accuracy: 85.992%
# Epoch 327/500 | Train loss: 0.29293 | validation loss: 0.37848 | train accuracy: 88.606% | validation accuracy: 86.478%
# Epoch 328/500 | Train loss: 0.29272 | validation loss: 0.37862 | train accuracy: 88.62% | validation accuracy: 86.39%
# Epoch 329/500 | Train loss: 0.29232 | validation loss: 0.38409 | train accuracy: 88.502% | validation accuracy: 84.711%
# Epoch 330/500 | Train loss: 0.29255 | validation loss: 0.37869 | train accuracy: 88.753% | validation accuracy: 85.859%
# Epoch 331/500 | Train loss: 0.29201 | validation loss: 0.38094 | train accuracy: 88.709% | validation accuracy: 84.887%
# Epoch 332/500 | Train loss: 0.29100 | validation loss: 0.38082 | train accuracy: 88.517% | validation accuracy: 86.213%
# Epoch 333/500 | Train loss: 0.29094 | validation loss: 0.37794 | train accuracy: 88.62% | validation accuracy: 86.125%
# Epoch 334/500 | Train loss: 0.29108 | validation loss: 0.37859 | train accuracy: 88.812% | validation accuracy: 86.434%
# Epoch 335/500 | Train loss: 0.29048 | validation loss: 0.37731 | train accuracy: 88.856% | validation accuracy: 86.257%
# Epoch 336/500 | Train loss: 0.28954 | validation loss: 0.38208 | train accuracy: 88.665% | validation accuracy: 84.755%
# Epoch 337/500 | Train loss: 0.28959 | validation loss: 0.37890 | train accuracy: 88.753% | validation accuracy: 85.02%
# Epoch 338/500 | Train loss: 0.29123 | validation loss: 0.37954 | train accuracy: 88.502% | validation accuracy: 84.932%
# Epoch 339/500 | Train loss: 0.28971 | validation loss: 0.37733 | train accuracy: 88.738% | validation accuracy: 86.478%
# Epoch 340/500 | Train loss: 0.28925 | validation loss: 0.37661 | train accuracy: 88.797% | validation accuracy: 86.434%
# Epoch 341/500 | Train loss: 0.28670 | validation loss: 0.38841 | train accuracy: 88.827% | validation accuracy: 84.49%
# Epoch 342/500 | Train loss: 0.28879 | validation loss: 0.38174 | train accuracy: 88.576% | validation accuracy: 84.755%
# Epoch 343/500 | Train loss: 0.28818 | validation loss: 0.37908 | train accuracy: 88.959% | validation accuracy: 86.257%
# Epoch 344/500 | Train loss: 0.28764 | validation loss: 0.37609 | train accuracy: 88.635% | validation accuracy: 86.257%
# Epoch 345/500 | Train loss: 0.28731 | validation loss: 0.38064 | train accuracy: 88.871% | validation accuracy: 84.799%
# Epoch 346/500 | Train loss: 0.28790 | validation loss: 0.37610 | train accuracy: 88.797% | validation accuracy: 86.346%
# Epoch 347/500 | Train loss: 0.28647 | validation loss: 0.37784 | train accuracy: 88.591% | validation accuracy: 86.036%
# Epoch 348/500 | Train loss: 0.28700 | validation loss: 0.37540 | train accuracy: 88.959% | validation accuracy: 86.301%
# Epoch 349/500 | Train loss: 0.28747 | validation loss: 0.37654 | train accuracy: 88.679% | validation accuracy: 86.08%
# Epoch 350/500 | Train loss: 0.28634 | validation loss: 0.38045 | train accuracy: 88.694% | validation accuracy: 84.799%
# Epoch 351/500 | Train loss: 0.28668 | validation loss: 0.37507 | train accuracy: 88.576% | validation accuracy: 86.39%
# Epoch 352/500 | Train loss: 0.28630 | validation loss: 0.38046 | train accuracy: 88.782% | validation accuracy: 84.887%
# Epoch 353/500 | Train loss: 0.28495 | validation loss: 0.37716 | train accuracy: 88.856% | validation accuracy: 86.301%
# Epoch 354/500 | Train loss: 0.28609 | validation loss: 0.37569 | train accuracy: 88.797% | validation accuracy: 86.434%
# Epoch 355/500 | Train loss: 0.28462 | validation loss: 0.37878 | train accuracy: 88.886% | validation accuracy: 84.932%
# Epoch 356/500 | Train loss: 0.28450 | validation loss: 0.37718 | train accuracy: 88.945% | validation accuracy: 85.02%
# Epoch 357/500 | Train loss: 0.28430 | validation loss: 0.37426 | train accuracy: 88.886% | validation accuracy: 86.478%
# Epoch 358/500 | Train loss: 0.28395 | validation loss: 0.37516 | train accuracy: 89.018% | validation accuracy: 86.699%
# Epoch 359/500 | Train loss: 0.28301 | validation loss: 0.37393 | train accuracy: 89.004% | validation accuracy: 86.346%
# Epoch 360/500 | Train loss: 0.28365 | validation loss: 0.37461 | train accuracy: 88.856% | validation accuracy: 86.92%
# Epoch 361/500 | Train loss: 0.28255 | validation loss: 0.37864 | train accuracy: 89.033% | validation accuracy: 84.887%
# Epoch 362/500 | Train loss: 0.28286 | validation loss: 0.37378 | train accuracy: 88.679% | validation accuracy: 86.39%
# Epoch 363/500 | Train loss: 0.28425 | validation loss: 0.37406 | train accuracy: 88.841% | validation accuracy: 86.39%
# Epoch 364/500 | Train loss: 0.28253 | validation loss: 0.37920 | train accuracy: 88.782% | validation accuracy: 86.301%
# Epoch 365/500 | Train loss: 0.28230 | validation loss: 0.37395 | train accuracy: 88.738% | validation accuracy: 86.787%
# Epoch 366/500 | Train loss: 0.28282 | validation loss: 0.37320 | train accuracy: 88.886% | validation accuracy: 86.346%
# Epoch 367/500 | Train loss: 0.28097 | validation loss: 0.37445 | train accuracy: 88.945% | validation accuracy: 86.699%
# Epoch 368/500 | Train loss: 0.28215 | validation loss: 0.37333 | train accuracy: 89.004% | validation accuracy: 86.743%
# Epoch 369/500 | Train loss: 0.28079 | validation loss: 0.38392 | train accuracy: 89.166% | validation accuracy: 84.578%
# Epoch 370/500 | Train loss: 0.28056 | validation loss: 0.37284 | train accuracy: 88.871% | validation accuracy: 86.478%
# Epoch 371/500 | Train loss: 0.28075 | validation loss: 0.37430 | train accuracy: 89.048% | validation accuracy: 85.506%
# Epoch 372/500 | Train loss: 0.28011 | validation loss: 0.37518 | train accuracy: 88.974% | validation accuracy: 86.699%
# Epoch 373/500 | Train loss: 0.27991 | validation loss: 0.37402 | train accuracy: 89.121% | validation accuracy: 86.522%
# Epoch 374/500 | Train loss: 0.27884 | validation loss: 0.37320 | train accuracy: 89.004% | validation accuracy: 86.567%
# Epoch 375/500 | Train loss: 0.27987 | validation loss: 0.37261 | train accuracy: 89.048% | validation accuracy: 86.611%
# Epoch 376/500 | Train loss: 0.27848 | validation loss: 0.37518 | train accuracy: 89.18% | validation accuracy: 85.02%
# Epoch 377/500 | Train loss: 0.27954 | validation loss: 0.37227 | train accuracy: 88.959% | validation accuracy: 86.611%
# Epoch 378/500 | Train loss: 0.27932 | validation loss: 0.37322 | train accuracy: 89.048% | validation accuracy: 86.743%
# Epoch 379/500 | Train loss: 0.27796 | validation loss: 0.37231 | train accuracy: 88.841% | validation accuracy: 86.39%
# Epoch 380/500 | Train loss: 0.27873 | validation loss: 0.37606 | train accuracy: 89.062% | validation accuracy: 85.064%
# Epoch 381/500 | Train loss: 0.27701 | validation loss: 0.37206 | train accuracy: 89.254% | validation accuracy: 86.567%
# Epoch 382/500 | Train loss: 0.27815 | validation loss: 0.37150 | train accuracy: 89.269% | validation accuracy: 86.39%
# Epoch 383/500 | Train loss: 0.27766 | validation loss: 0.37138 | train accuracy: 89.121% | validation accuracy: 86.611%
# Epoch 384/500 | Train loss: 0.27750 | validation loss: 0.37196 | train accuracy: 89.048% | validation accuracy: 86.699%
# Epoch 385/500 | Train loss: 0.27721 | validation loss: 0.37276 | train accuracy: 88.989% | validation accuracy: 86.699%
# Epoch 386/500 | Train loss: 0.27708 | validation loss: 0.37115 | train accuracy: 89.004% | validation accuracy: 86.611%
# Epoch 387/500 | Train loss: 0.27663 | validation loss: 0.37207 | train accuracy: 88.782% | validation accuracy: 86.611%
# Epoch 388/500 | Train loss: 0.27594 | validation loss: 0.37210 | train accuracy: 89.254% | validation accuracy: 86.876%
# Epoch 389/500 | Train loss: 0.27621 | validation loss: 0.37107 | train accuracy: 89.018% | validation accuracy: 86.567%
# Epoch 390/500 | Train loss: 0.27602 | validation loss: 0.37384 | train accuracy: 88.93% | validation accuracy: 86.567%
# Epoch 391/500 | Train loss: 0.27527 | validation loss: 0.37421 | train accuracy: 89.225% | validation accuracy: 85.241%
# Epoch 392/500 | Train loss: 0.27507 | validation loss: 0.37056 | train accuracy: 89.284% | validation accuracy: 86.522%
# Epoch 393/500 | Train loss: 0.27596 | validation loss: 0.37096 | train accuracy: 89.004% | validation accuracy: 86.611%
# Epoch 394/500 | Train loss: 0.27441 | validation loss: 0.37189 | train accuracy: 89.343% | validation accuracy: 86.743%
# Epoch 395/500 | Train loss: 0.27448 | validation loss: 0.37057 | train accuracy: 89.357% | validation accuracy: 86.611%
# Epoch 396/500 | Train loss: 0.27379 | validation loss: 0.37125 | train accuracy: 89.298% | validation accuracy: 86.567%
# Epoch 397/500 | Train loss: 0.27458 | validation loss: 0.37253 | train accuracy: 88.989% | validation accuracy: 85.152%
# Epoch 398/500 | Train loss: 0.27368 | validation loss: 0.37053 | train accuracy: 89.372% | validation accuracy: 86.611%
# Epoch 399/500 | Train loss: 0.27408 | validation loss: 0.37016 | train accuracy: 89.195% | validation accuracy: 86.699%
# Epoch 400/500 | Train loss: 0.27368 | validation loss: 0.37049 | train accuracy: 89.269% | validation accuracy: 87.053%
# Epoch 401/500 | Train loss: 0.27291 | validation loss: 0.37073 | train accuracy: 89.343% | validation accuracy: 86.832%
# Epoch 402/500 | Train loss: 0.27350 | validation loss: 0.37141 | train accuracy: 89.284% | validation accuracy: 86.787%
# Epoch 403/500 | Train loss: 0.27297 | validation loss: 0.37235 | train accuracy: 89.107% | validation accuracy: 86.346%
# Epoch 404/500 | Train loss: 0.27277 | validation loss: 0.37286 | train accuracy: 89.667% | validation accuracy: 86.301%
# Epoch 405/500 | Train loss: 0.27267 | validation loss: 0.37080 | train accuracy: 89.18% | validation accuracy: 86.699%
# Epoch 406/500 | Train loss: 0.27252 | validation loss: 0.36912 | train accuracy: 89.254% | validation accuracy: 86.743%
# Epoch 407/500 | Train loss: 0.27100 | validation loss: 0.37129 | train accuracy: 89.357% | validation accuracy: 86.478%
# Epoch 408/500 | Train loss: 0.27157 | validation loss: 0.37557 | train accuracy: 89.18% | validation accuracy: 85.108%
# Epoch 409/500 | Train loss: 0.27083 | validation loss: 0.37077 | train accuracy: 89.151% | validation accuracy: 86.611%
# Epoch 410/500 | Train loss: 0.27110 | validation loss: 0.36998 | train accuracy: 89.077% | validation accuracy: 86.699%
# Epoch 411/500 | Train loss: 0.27064 | validation loss: 0.37072 | train accuracy: 89.46% | validation accuracy: 86.611%
# Epoch 412/500 | Train loss: 0.27027 | validation loss: 0.37118 | train accuracy: 89.755% | validation accuracy: 86.655%
# Epoch 413/500 | Train loss: 0.27053 | validation loss: 0.37030 | train accuracy: 89.284% | validation accuracy: 86.611%
# Epoch 414/500 | Train loss: 0.26993 | validation loss: 0.36871 | train accuracy: 89.254% | validation accuracy: 86.655%
# Epoch 415/500 | Train loss: 0.26938 | validation loss: 0.37554 | train accuracy: 89.416% | validation accuracy: 85.197%
# Epoch 416/500 | Train loss: 0.26953 | validation loss: 0.37767 | train accuracy: 89.534% | validation accuracy: 85.152%
# Epoch 417/500 | Train loss: 0.26919 | validation loss: 0.37256 | train accuracy: 89.195% | validation accuracy: 85.329%
# Epoch 418/500 | Train loss: 0.26991 | validation loss: 0.36826 | train accuracy: 89.062% | validation accuracy: 86.743%
# Epoch 419/500 | Train loss: 0.26999 | validation loss: 0.37251 | train accuracy: 89.18% | validation accuracy: 86.655%
# Epoch 420/500 | Train loss: 0.26835 | validation loss: 0.36838 | train accuracy: 89.593% | validation accuracy: 86.787%
# Epoch 421/500 | Train loss: 0.26864 | validation loss: 0.38142 | train accuracy: 89.298% | validation accuracy: 84.932%
# Epoch 422/500 | Train loss: 0.26857 | validation loss: 0.36910 | train accuracy: 89.328% | validation accuracy: 86.743%
# Epoch 423/500 | Train loss: 0.26815 | validation loss: 0.36987 | train accuracy: 89.637% | validation accuracy: 86.743%
# Epoch 424/500 | Train loss: 0.26824 | validation loss: 0.37039 | train accuracy: 89.578% | validation accuracy: 86.787%
# Epoch 425/500 | Train loss: 0.26792 | validation loss: 0.36807 | train accuracy: 89.284% | validation accuracy: 87.097%
# Epoch 426/500 | Train loss: 0.26747 | validation loss: 0.36799 | train accuracy: 89.578% | validation accuracy: 87.45%
# Epoch 427/500 | Train loss: 0.26777 | validation loss: 0.36943 | train accuracy: 89.49% | validation accuracy: 86.787%
# Epoch 428/500 | Train loss: 0.26786 | validation loss: 0.37264 | train accuracy: 89.372% | validation accuracy: 86.301%
# Epoch 429/500 | Train loss: 0.26671 | validation loss: 0.36906 | train accuracy: 89.46% | validation accuracy: 86.611%
# Epoch 430/500 | Train loss: 0.26761 | validation loss: 0.37526 | train accuracy: 89.343% | validation accuracy: 85.241%
# Epoch 431/500 | Train loss: 0.26725 | validation loss: 0.36985 | train accuracy: 89.652% | validation accuracy: 86.92%
# Epoch 432/500 | Train loss: 0.26607 | validation loss: 0.36749 | train accuracy: 89.667% | validation accuracy: 86.743%
# Epoch 433/500 | Train loss: 0.26707 | validation loss: 0.36754 | train accuracy: 89.431% | validation accuracy: 86.567%
# Epoch 434/500 | Train loss: 0.26567 | validation loss: 0.37164 | train accuracy: 89.682% | validation accuracy: 85.285%
# Epoch 435/500 | Train loss: 0.26690 | validation loss: 0.37141 | train accuracy: 89.298% | validation accuracy: 85.506%
# Epoch 436/500 | Train loss: 0.26579 | validation loss: 0.37560 | train accuracy: 89.534% | validation accuracy: 85.197%
# Epoch 437/500 | Train loss: 0.26532 | validation loss: 0.37452 | train accuracy: 89.416% | validation accuracy: 85.418%
# Epoch 438/500 | Train loss: 0.26579 | validation loss: 0.36990 | train accuracy: 89.578% | validation accuracy: 86.787%
# Epoch 439/500 | Train loss: 0.26517 | validation loss: 0.36750 | train accuracy: 89.785% | validation accuracy: 86.876%
# Epoch 440/500 | Train loss: 0.26472 | validation loss: 0.37097 | train accuracy: 89.534% | validation accuracy: 85.462%
# Epoch 441/500 | Train loss: 0.26411 | validation loss: 0.37033 | train accuracy: 89.564% | validation accuracy: 86.434%
# Epoch 442/500 | Train loss: 0.26320 | validation loss: 0.36694 | train accuracy: 89.755% | validation accuracy: 86.611%
# Epoch 443/500 | Train loss: 0.26350 | validation loss: 0.36893 | train accuracy: 89.726% | validation accuracy: 86.611%
# Epoch 444/500 | Train loss: 0.26464 | validation loss: 0.36748 | train accuracy: 89.976% | validation accuracy: 87.053%
# Epoch 445/500 | Train loss: 0.26454 | validation loss: 0.36713 | train accuracy: 89.608% | validation accuracy: 86.611%
# Epoch 446/500 | Train loss: 0.26429 | validation loss: 0.36743 | train accuracy: 89.46% | validation accuracy: 86.832%
# Epoch 447/500 | Train loss: 0.26468 | validation loss: 0.37039 | train accuracy: 89.519% | validation accuracy: 85.418%
# Epoch 448/500 | Train loss: 0.26329 | validation loss: 0.36714 | train accuracy: 89.637% | validation accuracy: 86.611%
# Epoch 449/500 | Train loss: 0.26357 | validation loss: 0.36855 | train accuracy: 89.387% | validation accuracy: 86.876%
# Epoch 450/500 | Train loss: 0.26263 | validation loss: 0.36752 | train accuracy: 89.726% | validation accuracy: 86.92%
# Epoch 451/500 | Train loss: 0.26236 | validation loss: 0.36686 | train accuracy: 89.741% | validation accuracy: 86.611%
# Epoch 452/500 | Train loss: 0.26412 | validation loss: 0.36724 | train accuracy: 89.475% | validation accuracy: 86.964%
# Epoch 453/500 | Train loss: 0.26318 | validation loss: 0.36771 | train accuracy: 89.534% | validation accuracy: 87.053%
# Epoch 454/500 | Train loss: 0.26152 | validation loss: 0.36988 | train accuracy: 89.682% | validation accuracy: 85.418%
# Epoch 455/500 | Train loss: 0.26142 | validation loss: 0.36836 | train accuracy: 89.785% | validation accuracy: 86.787%
# Epoch 456/500 | Train loss: 0.26283 | validation loss: 0.38083 | train accuracy: 89.711% | validation accuracy: 84.843%
# Epoch 457/500 | Train loss: 0.26238 | validation loss: 0.36746 | train accuracy: 89.652% | validation accuracy: 86.92%
# Epoch 458/500 | Train loss: 0.26088 | validation loss: 0.36677 | train accuracy: 89.667% | validation accuracy: 86.655%
# Epoch 459/500 | Train loss: 0.26184 | validation loss: 0.37817 | train accuracy: 89.608% | validation accuracy: 85.02%
# Epoch 460/500 | Train loss: 0.26076 | validation loss: 0.36644 | train accuracy: 89.667% | validation accuracy: 86.832%
# Epoch 461/500 | Train loss: 0.26142 | validation loss: 0.37999 | train accuracy: 89.534% | validation accuracy: 85.904%
# Epoch 462/500 | Train loss: 0.26024 | validation loss: 0.38045 | train accuracy: 89.387% | validation accuracy: 84.932%
# Epoch 463/500 | Train loss: 0.25953 | validation loss: 0.37370 | train accuracy: 89.844% | validation accuracy: 86.257%
# Epoch 464/500 | Train loss: 0.26115 | validation loss: 0.36665 | train accuracy: 89.77% | validation accuracy: 86.611%
# Epoch 465/500 | Train loss: 0.26091 | validation loss: 0.37173 | train accuracy: 89.637% | validation accuracy: 86.346%
# Epoch 466/500 | Train loss: 0.26031 | validation loss: 0.36731 | train accuracy: 89.755% | validation accuracy: 87.008%
# Epoch 467/500 | Train loss: 0.25982 | validation loss: 0.36640 | train accuracy: 89.711% | validation accuracy: 86.611%
# Epoch 468/500 | Train loss: 0.25817 | validation loss: 0.37131 | train accuracy: 89.991% | validation accuracy: 86.213%
# Epoch 469/500 | Train loss: 0.26080 | validation loss: 0.37511 | train accuracy: 89.608% | validation accuracy: 85.108%
# Epoch 470/500 | Train loss: 0.25909 | validation loss: 0.36676 | train accuracy: 89.652% | validation accuracy: 87.053%
# Epoch 471/500 | Train loss: 0.25892 | validation loss: 0.37116 | train accuracy: 89.858% | validation accuracy: 86.567%
# Epoch 472/500 | Train loss: 0.25945 | validation loss: 0.36695 | train accuracy: 89.858% | validation accuracy: 87.053%
# Epoch 473/500 | Train loss: 0.25887 | validation loss: 0.38825 | train accuracy: 89.637% | validation accuracy: 84.445%
# Epoch 474/500 | Train loss: 0.25960 | validation loss: 0.37257 | train accuracy: 89.8% | validation accuracy: 85.462%
# Epoch 475/500 | Train loss: 0.25882 | validation loss: 0.37367 | train accuracy: 89.755% | validation accuracy: 85.462%
# Epoch 476/500 | Train loss: 0.25743 | validation loss: 0.36688 | train accuracy: 89.711% | validation accuracy: 86.964%
# Epoch 477/500 | Train loss: 0.25842 | validation loss: 0.36655 | train accuracy: 90.006% | validation accuracy: 86.655%
# Epoch 478/500 | Train loss: 0.25786 | validation loss: 0.37425 | train accuracy: 89.844% | validation accuracy: 85.152%
# Epoch 479/500 | Train loss: 0.25772 | validation loss: 0.36723 | train accuracy: 89.77% | validation accuracy: 86.92%
# Epoch 480/500 | Train loss: 0.25735 | validation loss: 0.36805 | train accuracy: 89.814% | validation accuracy: 86.92%
# Epoch 481/500 | Train loss: 0.25795 | validation loss: 0.36665 | train accuracy: 89.755% | validation accuracy: 86.92%
# Epoch 482/500 | Train loss: 0.25686 | validation loss: 0.36922 | train accuracy: 89.947% | validation accuracy: 86.92%
# Epoch 483/500 | Train loss: 0.25745 | validation loss: 0.36773 | train accuracy: 90.035% | validation accuracy: 86.699%
# Epoch 484/500 | Train loss: 0.25703 | validation loss: 0.36915 | train accuracy: 89.947% | validation accuracy: 86.699%
# Epoch 485/500 | Train loss: 0.25687 | validation loss: 0.36659 | train accuracy: 89.829% | validation accuracy: 87.008%
# Epoch 486/500 | Train loss: 0.25617 | validation loss: 0.36619 | train accuracy: 90.08% | validation accuracy: 87.097%
# Epoch 487/500 | Train loss: 0.25630 | validation loss: 0.36710 | train accuracy: 90.035% | validation accuracy: 86.964%
# Epoch 488/500 | Train loss: 0.25734 | validation loss: 0.36867 | train accuracy: 89.726% | validation accuracy: 86.876%
# Epoch 489/500 | Train loss: 0.25588 | validation loss: 0.36974 | train accuracy: 89.785% | validation accuracy: 86.522%
# Epoch 490/500 | Train loss: 0.25579 | validation loss: 0.37811 | train accuracy: 89.8% | validation accuracy: 86.125%
# Epoch 491/500 | Train loss: 0.25647 | validation loss: 0.36723 | train accuracy: 89.888% | validation accuracy: 87.494%
# Epoch 492/500 | Train loss: 0.25523 | validation loss: 0.36669 | train accuracy: 89.785% | validation accuracy: 87.274%
# Epoch 493/500 | Train loss: 0.25530 | validation loss: 0.36915 | train accuracy: 89.844% | validation accuracy: 85.329%
# Epoch 494/500 | Train loss: 0.25636 | validation loss: 0.36986 | train accuracy: 89.298% | validation accuracy: 85.418%
# Epoch 495/500 | Train loss: 0.25572 | validation loss: 0.37132 | train accuracy: 89.873% | validation accuracy: 85.462%
# Epoch 496/500 | Train loss: 0.25479 | validation loss: 0.37056 | train accuracy: 89.976% | validation accuracy: 86.434%
# Epoch 497/500 | Train loss: 0.25516 | validation loss: 0.38174 | train accuracy: 89.682% | validation accuracy: 85.064%
# Epoch 498/500 | Train loss: 0.25561 | validation loss: 0.36996 | train accuracy: 89.696% | validation accuracy: 85.373%
# Epoch 499/500 | Train loss: 0.25599 | validation loss: 0.36780 | train accuracy: 89.357% | validation accuracy: 86.92%
# Epoch 500/500 | Train loss: 0.25472 | validation loss: 0.36738 | train accuracy: 90.05% | validation accuracy: 87.008%

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(validation_losses, label='Validation loss')
plt.legend(frameon=False)
plt.show()

# %%
plt.plot(train_accuracies, label='train_accuracy')
plt.plot(valid_accuracies, label='validation_accuracy')
plt.legend(frameon=False)
plt.show()

# %%
# plot together
plt.ion()
fig = plt.figure()
subfig = fig.add_subplot(121)
subfig.plot(train_accuracies, label="training")
subfig.plot(valid_accuracies, label="validation")
subfig.set_title('Model Accuracy')
subfig.set_xlabel('Epoch')
subfig.legend(loc='upper left')
subfig = fig.add_subplot(122)
subfig.plot(train_losses, label="training")
subfig.plot(validation_losses, label="validation")
subfig.set_title('Model Loss')
subfig.set_xlabel('Epoch')
subfig.legend(loc='upper left')
plt.ioff()

# %%
predictions = [] # instead of correct
targets = [] # instead of total
for inputs, labels in dataloader_test:
    inputs, labels = inputs.to(device), labels.to(device)
    preds = model.eval()(inputs.float())
    predictions.extend(torch.argmax(preds, 1).tolist())
    targets.extend(torch.argmax(labels, 1).tolist())
print(classification_report(targets, predictions, labels=list(set(targets))))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75        30
#            1       0.75      0.58      0.65        26
#            2       0.91      0.95      0.93      1623
#            3       0.67      0.69      0.68       290
#            4       0.91      0.69      0.78       294
#
#     accuracy                           0.87      2263
#    macro avg       0.85      0.70      0.76      2263
# weighted avg       0.87      0.87      0.87      2263

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(targets, predictions))

sns.heatmap(confusion_matrix_df, annot=True)

# %%
#

# %%
model_test =torch.load("/content/drive/MyDrive/model.pth")
model_test.eval()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-7c81d16521a6> in <module>()
# ----> 1 model_test =torch.load("/content/drive/MyDrive/model.pth")
#       2 model_test.eval()
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# --> 579     with _open_file_like(f, 'rb') as opened_file:
#     580         if _is_zipfile(opened_file):
#     581             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/model.pth'

# %%
dataiter = iter(dataloader_test)
sequences, labels = dataiter.next()

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(17)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d62a5a04b1b6> in <module>()
# ----> 1 _, predicted = torch.max(outputs, 1)
#       2
#       3 print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
#       4                               for j in range(17)))
#
# NameError: name 'outputs' is not defined

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-5ef0030d31c6> in <module>()
#       2 total = 0
#       3 with torch.no_grad():
# ----> 4     for data in testloader:
#       5         images, labels = data
#       6         outputs = net(images)
#
# NameError: name 'testloader' is not defined

# %% [markdown]
# ## Ignore all below, old code!

# %%
nb_epochs = args.nb_epochs
def train(epoch):
    n = 0
    for epoch in range(nb_epochs):
        for seqs, labels in iter(dataloader_train):
            print("step 1")
            zs = model(seqs.float())
            print("completed  model")
            loss = criterion(zs, labels) # computes total loss
            print("computed loss")
            loss.backward() # compute updates for each parameter
            print("updated")
            optimizer.step() # make the updates for each param.
            optimizer.zero_grad() # clean up step 
            print(epoch)
        
            n += 1 
    
    return model

# %%
test = train(10)

# %%
seqs, labels = next(iter(dataloader_train))

# %%
print(seqs.shape)
print(labels.shape)

# %% [markdown]
# ## Disregard the code under (old stuff):

# %%
seqs, labels = next(iter(dataloader_train))

# %%
print(labels.shape)

# %%
class Generator(nn.Module):
    def __init__(self, z_dim=685, im_dim=685, hidden_dim=128):
        super(Generator, self).__init__()
        # Build the neural network
        self.gen = nn.Sequential(
            get_generator_block(z_dim, hidden_dim),
            get_generator_block(hidden_dim, hidden_dim * 2),
            get_generator_block(hidden_dim * 2, hidden_dim * 4),
            get_generator_block(hidden_dim * 4, hidden_dim * 8),
            nn.Linear(hidden_dim * 8, im_dim),
            nn.Sigmoid()
        )
    def forward(self, noise):
        return self.gen(noise)
    
class Discriminator(nn.Module):
    def __init__(self, im_dim=685, hidden_dim=128):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            get_discriminator_block(im_dim, hidden_dim * 4),
            get_discriminator_block(hidden_dim * 4, hidden_dim * 2),
            get_discriminator_block(hidden_dim * 2, hidden_dim),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, image):
        return self.disc(image)

# %%
gen = Generator(z_dim).to(device)
gen_opt = torch.optim.Adam(gen.parameters(), lr=args.learning_rate)
disc = Discriminator().to(device) 
disc_opt = torch.optim.Adam(disc.parameters(), lr=args.learning_rate)

# %%
cur_step = 0
mean_generator_loss = 0
mean_discriminator_loss = 0
test_generator = True # Whether the generator should be tested
gen_loss = False
for epoch in range(args.nb_epochs):
  
    # Dataloader returns the batches
    for real in dataloader_train:
        cur_batch_size = len(real)
        print(real.shape)

        # Flatten the batch of real images from the dataset
        real = real.view(cur_batch_size, -1).to(device)

        # Zero out the gradients before backpropagation
        disc_opt.zero_grad()

        # Calculate discriminator loss
        disc_loss = get_disc_loss(gen, disc, criterion, real, cur_batch_size, z_dim, device)

        # Update gradients
        disc_loss.backward(retain_graph=True)

        # Update optimizer
        disc_opt.step()

        # For testing purposes, to keep track of the generator weights
        if test_generator:
            old_generator_weights = gen.gen[0][0].weight.detach().clone()

        gen_opt.zero_grad()
        gen_loss = get_gen_loss(gen, disc, criterion, cur_batch_size, z_dim, device)
        gen_loss.backward()
        gen_opt.step()
        # For testing purposes, to check that your code changes the generator weights
        if test_generator:
            assert torch.any(gen.gen[0][0].weight.detach().clone() != old_generator_weights)

        # Keep track of the average discriminator loss
        mean_discriminator_loss += disc_loss.item() / display_step

        # Keep track of the average generator loss
        mean_generator_loss += gen_loss.item() / display_step
        
        print(epoch)
        
        ### Visualization code ###
        if cur_step % display_step == 0 and cur_step > 0:
            print(f"Step {cur_step}: Generator loss: {mean_generator_loss}, discriminator loss: {mean_discriminator_loss}")
            fake_noise = get_noise(cur_batch_size, z_dim, device=device)
            fake = gen(fake_noise)
            show_tensor_images(fake)
            show_tensor_images(real)
            mean_generator_loss = 0
            mean_discriminator_loss = 0
        cur_step += 1

# %%
print(args.nb_epochs)

# %%
class mlp_generator(nn.Module):
    """ Multi-Layer Perceptron for generating sequences.

    Parameters:
        inputs (tensor):Batch of noises inputed to the network.
        dim (int):Generator dimension parameter (in each middle layer).
        input_size (int):Size of latent space (i.e., the first layer dimension).
        output_size (int):Size of the last layer (=max_seq_len*vocab_size).
        num_layers (int):How many middle or hidden layers for generator.

    Returns:
        outputs (tensor):Batch of lists of values (each `vocab_size` interval represents one nucleotide).   

    """
    def __init__(self, dim=200, input_size=100, output_size=10, num_layers=4):
        super(mlp_generator, self).__init__()

        num_layers = num_layers + 2  # add 2 for the 1st and the last layers
        modules = []
        for layer in range(num_layers): 
            in_size = input_size if layer == 0 else dim
            out_size = output_size if layer == num_layers - 1 else dim
            if layer < num_layers - 1:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                        nn.ReLU(True),
                    )
                )
            else:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                        nn.Sigmoid()
                    )
                )
        self.layers = nn.Sequential(*modules)
        
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.layers(x)
        return x


class mlp_discriminator(nn.Module):
    """ Multi-Layer Perceptron for discriminating real vs generated sequences.

    Parameters:
        inputs (tensor):Tensor of size (batch_size, vocab_size*max_seq_len) containing real or generated sequences.
        dim (int):Discriminator dimension parameter (in each middle layer).
        input_size (int):Size of the first layer (vocab_size*max_seq_len).
        num_layers (int):How many middle or hidden layers for discriminator.

    Returns:
        outputs (tensor):Batch of (single) values for real or generated inputs.   

    """
    def __init__(self, dim, input_size, num_layers=4):
        super(mlp_discriminator, self).__init__()
        
        num_layers = num_layers + 2  # add 2 for the 1st and the last layers
        modules = []
        for layer in range(num_layers):
            in_size = input_size if layer == 0 else dim
            out_size = 1 if layer == num_layers - 1 else dim
            if layer < num_layers - 1:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                        nn.LeakyReLU(0.2, inplace=True),
                    )
                )
            else:
                modules.append(
                    nn.Sequential(
                        nn.Linear(in_size, out_size),
                    )
                )
        self.layers = nn.Sequential(*modules)
        
    def forward(self, inputs):
        inputs = inputs.view(inputs.size(0), -1)
        outputs = self.layers(inputs)
        return outputs

# %%
# instantiate models
if args.model_type=="mlp":
    netG = mlp_generator(args.gen_dim, args.latent_dim, args.max_seq_len*vocab_size, args.gen_layers).to(device)
    netD = mlp_discriminator(args.disc_dim, args.max_seq_len*vocab_size, args.disc_layers).to(device)
elif args.model_type=="resnet1d":
    netG = resnet_generator_1d(args.gen_dim, args.latent_dim, vocab_size, args.max_seq_len, args.gen_layers).to(device)
    netD = resnet_discriminator_1d(args.disc_dim, vocab_size, args.max_seq_len, args.disc_layers).to(device)
elif args.model_type=="resnet2d":
    netG = resnet_generator_2d(args.gen_dim, args.latent_dim, vocab_size, args.max_seq_len, args.gen_layers).to(device)
    netD = resnet_discriminator_2d(args.disc_dim, vocab_size, args.max_seq_len, args.disc_layers).to(device)

print("{}\nGenerator Network Architecture:\n{}\n{}\n".format("="*31, "~"*31, netG))
print("{}\nDiscriminator Network Architecture:\n{}\n{}\n".format("="*35, "~"*35, netD))

# cost function (for discriminator prediction)
criterion = nn.BCEWithLogitsLoss()

# setup optimizer
optimizerG = optim.Adam(list(netG.parameters()), lr=args.learning_rate, betas=(args.beta1, 0.999))
optimizerD = optim.Adam(list(netD.parameters()), lr=args.learning_rate, betas=(args.beta1, 0.999))

# use an exponentially decaying learning rate
schedulerG = optim.lr_scheduler.ExponentialLR(optimizerG, gamma=0.99)
schedulerD= optim.lr_scheduler.ExponentialLR(optimizerD, gamma=0.99)
